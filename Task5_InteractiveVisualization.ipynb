# %% [markdown]
# # Interactive Recommendation System with Word Embeddings using Word2Vec, Plotly, and NetworkX
#
# ## Project Breakdown
# - Task 1: Introduction
# - Task 2: Exploratory Data Analysis and Preprocessing
# - Task 3: Word2Vec with Gensim
# - Task 4: Exploring Results
# - Task 5: Building and Visualizing Interactive Network Graph (you are here)
#
# ## Task 5: Building and Visualizing Interactive Network Graph
# Let's see if we can visualize our results better!

# %%
from sklearn.metrics.pairwise import cosine_similarity
import plotly.graph_objects as go
from plotly.offline import plot
import networkx as nx
import numpy as np

# %%
words = np.loadtxt("./Data/words.txt", dtype=str)
vectors = np.load("./Data/vectors.npy")

# %%
sim = cosine_similarity(vectors, vectors)

# %%
for i in range(len(vectors)):
    for j in range(len(vectors)):
        if i<=j:
            sim[i, j] = False

# %%
indices = np.argwhere(sim > 0.65)
indices
# Out:
# array([[ 18,  16],
#        [ 30,   9],
#        [ 31,   9],
#        ...,
#        [907, 646],
#        [907, 847],
#        [907, 886]])

# %%
G = nx.Graph()

for index in indices:
    G.add_edge(
        words[index[0]], words[index[1]],
        weight = sim[index[0], index[1]]
    )

# %%
weight_values = nx.get_edge_attributes(G, "weight")
weight_values
# Out:
# {('egg', 'eggs'): 0.7777155,
#  ('orange', 'lemon'): 0.83867216,
#  ('orange', 'lime'): 0.74004054,
#  ('orange', 'limes'): 0.6737236,
#  ('orange', 'oranges'): 0.6727178,
#  ('orange', 'grapefruit'): 0.72318953,
#  ('orange', 'tangerine'): 0.88223654,
#  ('orange', 'clementine'): 0.7992686,
#  ('lemon', 'lime'): 0.8338885,
#  ('lemon', 'lemons'): 0.7375067,
#  ('lemon', 'limes'): 0.72252166,
#  ('lemon', 'tangerine'): 0.78065497,
#  ('lemon', 'clementine'): 0.6861555,
#  ('lime', 'limes'): 0.85942197,
#  ('lime', 'tangerine'): 0.6746109,
#  ('cilantro', 'parsley'): 0.65485466,
#  ('cilantro', 'mint'): 0.6793539,
#  ('parsley', 'chives'): 0.74516344,
#  ('parsley', 'tarragon'): 0.7549317,
#  ('parsley', 'herbs'): 0.67342025,
#  ('parsley', 'marjoram'): 0.65538746,
#  ('tomato', 'tomatoes'): 0.6868246,
#  ('clove', 'cloves'): 0.9204472,
#  ('stock', 'broth'): 0.94694597,
#  ('stock', 'consomme'): 0.67639786,
#  ('broth', 'consomme'): 0.6657147,
#  ('leaf', 'leaves'): 0.8256098,
#  ('pork', 'beef'): 0.6969555,
#  ('pork', 'lamb'): 0.7786149,
#  ('pork', 'veal'): 0.70590734,
#  ('pork', 'venison'): 0.79040486,
#  ('pork', 'elk'): 0.6854272,
#  ('beef', 'veal'): 0.6560129,
#  ('oregano', 'thyme'): 0.7470792,
#  ('oregano', 'rosemary'): 0.7182464,
#  ('oregano', 'marjoram'): 0.8100021,
#  ('oregano', 'orégano'): 0.6579792,
#  ('thyme', 'rosemary'): 0.9263163,
#  ('thyme', 'tarragon'): 0.7531343,
#  ('thyme', 'marjoram'): 0.8326936,
#  ('chile', 'chili'): 0.80527383,
#  ('chile', 'chiles'): 0.77368885,
#  ('chile', 'curry'): 0.6689811,
#  ('chile', 'chilies'): 0.72274953,
#  ('chile', 'habanero'): 0.65944314,
#  ('chili', 'curry'): 0.8062353,
#  ('canola', 'vegetable'): 0.8533221,
#  ('canola', 'grapeseed'): 0.8667587,
#  ('canola', 'safflower'): 0.6891608,
#  ('vegetable', 'grapeseed'): 0.6646179,
#  ('mint', 'spearmint'): 0.7110399,
#  ('rosemary', 'tarragon'): 0.69978863,
#  ('rosemary', 'marjoram'): 0.8260966,
#  ('chives', 'tarragon'): 0.72217757,
#  ('walnuts', 'almonds'): 0.74918675,
#  ('walnuts', 'pecans'): 0.90488356,
#  ('walnuts', 'nuts'): 0.72518796,
#  ('walnuts', 'hazelnuts'): 0.7847814,
#  ('walnuts', 'pistachios'): 0.7709673,
#  ('almonds', 'pecans'): 0.73423254,
#  ('almonds', 'nuts'): 0.66986924,
#  ('almonds', 'hazelnuts'): 0.8125475,
#  ('almonds', 'pistachios'): 0.77436435,
#  ('almonds', 'cashews'): 0.68018365,
#  ('jalapeno', 'bell'): 0.6642276,
#  ('jalapeno', 'jalapeño'): 0.8905599,
#  ('jalapeno', 'jalapenos'): 0.7614103,
#  ('jalapeno', 'habanero'): 0.8281061,
#  ('jalapeno', 'jalapeños'): 0.72685367,
#  ('jalapeno', 'jalepeno'): 0.78660256,
#  ('jalapeno', 'serranos'): 0.6511059,
#  ('turkey', 'chicken'): 0.6813894,
#  ('turkey', 'goose'): 0.66729224,
#  ('chiles', 'chilies'): 0.89293885,
#  ('chiles', 'jalapenos'): 0.66193384,
#  ('chiles', 'tomatillos'): 0.6694355,
#  ('chiles', 'jalapeños'): 0.69379103,
#  ('carrot', 'carrots'): 0.83617777,
#  ('carrots', 'parsnips'): 0.7085175,
#  ('carrots', 'turnips'): 0.73259187,
#  ('carrots', 'turnip'): 0.65808886,
#  ('carrots', 'rutabaga'): 0.68728805,
#  ('pecans', 'nuts'): 0.7326917,
#  ('pecans', 'hazelnuts'): 0.7605487,
#  ('pecans', 'pistachios'): 0.73631686,
#  ('almond', 'vanilla'): 0.69687444,
#  ('almond', 'peppermint'): 0.6733031,
#  ('vanilla', 'peppermint'): 0.69195765,
#  ('fish', 'fillets'): 0.69219834,
#  ('fish', 'salmon'): 0.7169661,
#  ('fish', 'cod'): 0.6923183,
#  ('fish', 'trout'): 0.67187107,
#  ('fish', 'sole'): 0.67687035,
#  ('fish', 'monkfish'): 0.65391517,
#  ('fillets', 'salmon'): 0.7232208,
#  ('fillets', 'fillet'): 0.85237116,
#  ('fillets', 'cod'): 0.7113286,
#  ('fillets', 'snapper'): 0.68895924,
#  ('fillets', 'trout'): 0.7341322,
#  ('fillets', 'tilapia'): 0.7388691,
#  ('fillets', 'sole'): 0.7967294,
#  ('fillets', 'monkfish'): 0.6881868,
#  ('fillets', 'whitefish'): 0.66822183,
#  ('nuts', 'hazelnuts'): 0.7310077,
#  ('nuts', 'pistachios'): 0.72638375,
#  ('potato', 'potatoes'): 0.74561316,
#  ('potatoes', 'parsnips'): 0.71076775,
#  ('potatoes', 'turnips'): 0.6849775,
#  ('squash', 'zucchini'): 0.7027565,
#  ('zucchini', 'eggplant'): 0.7589735,
#  ('zucchini', 'zucchinis'): 0.6612169,
#  ('allspice', 'cinnamon'): 0.6523539,
#  ('allspice', 'nutmeg'): 0.68138796,
#  ('allspice', 'cardamom'): 0.70158786,
#  ('cinnamon', 'cardamom'): 0.67592907,
#  ('lemons', 'limes'): 0.7932298,
#  ('lemons', 'oranges'): 0.6674235,
#  ('lemons', 'tangerine'): 0.67530006,
#  ('lemons', 'clementines'): 0.6507175,
#  ('lemons', 'clementine'): 0.71791553,
#  ('tarragon', 'marjoram'): 0.72290593,
#  ('salmon', 'tuna'): 0.656234,
#  ('salmon', 'fillet'): 0.7609008,
#  ('salmon', 'cod'): 0.74739784,
#  ('salmon', 'trout'): 0.8468755,
#  ('salmon', 'tilapia'): 0.71592015,
#  ('salmon', 'sole'): 0.7423639,
#  ('salmon', 'monkfish'): 0.71013516,
#  ('salmon', 'whitefish'): 0.7865906,
#  ('salmon', 'rockfish'): 0.68708706,
#  ('cranberries', 'cherries'): 0.74596685,
#  ('cranberries', 'blueberries'): 0.6510078,
#  ('cranberries', 'apricots'): 0.78671557,
#  ('cranberries', 'figs'): 0.68376803,
#  ('cranberries', 'currants'): 0.77244437,
#  ('cherries', 'blueberries'): 0.6598991,
#  ('cherries', 'apricots'): 0.750269,
#  ('cherries', 'figs'): 0.6691405,
#  ('cherries', 'currants'): 0.65525573,
#  ('margarine', 'butter'): 0.6956121,
#  ('arugula', 'spinach'): 0.71531713,
#  ('arugula', 'watercress'): 0.8029138,
#  ('arugula', 'radicchio'): 0.74487966,
#  ('arugula', 'endive'): 0.6668888,
#  ('arugula', 'lettuces'): 0.7484724,
#  ('limes', 'grapefruit'): 0.68909574,
#  ('limes', 'tangerine'): 0.66663504,
#  ('limes', 'clementine'): 0.6773713,
#  ('raspberries', 'strawberries'): 0.8532155,
#  ('raspberries', 'blueberries'): 0.86171705,
#  ('raspberries', 'raspberry'): 0.666363,
#  ('raspberries', 'berries'): 0.7512912,
#  ('raspberries', 'strawberry'): 0.70191085,
#  ('raspberries', 'blackberries'): 0.9065306,
#  ('raspberries', 'rhubarb'): 0.7159214,
#  ('raspberries', 'berry'): 0.6764462,
#  ('raspberries', 'blueberry'): 0.68182904,
#  ('raspberries', 'gooseberries'): 0.67603534,
#  ('strawberries', 'blueberries'): 0.79775864,
#  ('strawberries', 'peaches'): 0.7083943,
#  ('strawberries', 'berries'): 0.72346413,
#  ('strawberries', 'strawberry'): 0.6562761,
#  ('strawberries', 'blackberries'): 0.8357069,
#  ('strawberries', 'rhubarb'): 0.72823143,
#  ('strawberries', 'nectarines'): 0.6514464,
#  ('brandy', 'liqueur'): 0.6587194,
#  ('brandy', 'rum'): 0.6570986,
#  ('brandy', 'whiskey'): 0.70907587,
#  ('brandy', 'applejack'): 0.7887401,
#  ('liqueur', 'vodka'): 0.6557019,
#  ('liqueur', 'amaretto'): 0.7088627,
#  ('liqueur', 'schnapps'): 0.66992444,
#  ('liqueur', 'limoncello'): 0.70215166,
#  ('liqueur', 'kahlua'): 0.6532171,
#  ('liqueur', 'frangelico'): 0.71967524,
#  ('liqueur', 'sambuca'): 0.6511799,
#  ('blueberries', 'peaches'): 0.6928304,
#  ('blueberries', 'berries'): 0.7695402,
#  ('blueberries', 'blackberries'): 0.90526944,
#  ('blueberries', 'rhubarb'): 0.73601294,
#  ('lamb', 'veal'): 0.73056114,
#  ('lamb', 'venison'): 0.759259,
#  ('lamb', 'shanks'): 0.6541826,
#  ('vodka', 'tequila'): 0.67936957,
#  ('vodka', 'gin'): 0.7972167,
#  ('vodka', 'lemonade'): 0.68830484,
#  ('vodka', 'schnapps'): 0.6806039,
#  ('vodka', 'limoncello'): 0.65221494,
#  ('vodka', 'hendricks'): 0.68487316,
#  ('mango', 'pineapple'): 0.72195905,
#  ('mango', 'avocado'): 0.6505002,
#  ('mango', 'peach'): 0.6736878,
#  ('mango', 'watermelon'): 0.6552109,
#  ('mango', 'papaya'): 0.8113684,
#  ('mango', 'mangoes'): 0.80341834,
#  ('mango', 'cantaloupe'): 0.6997232,
#  ('mango', 'kiwi'): 0.7074637,
#  ('mango', 'mangos'): 0.7656204,
#  ('mango', 'kiwis'): 0.655862,
#  ('avocado', 'avocados'): 0.8528476,
#  ('avocado', 'avocadoes'): 0.72795826,
#  ('parmigiano', 'parmesan'): 0.7543441,
#  ('parmigiano', 'romano'): 0.81569344,
#  ('parmigiano', 'pecorino'): 0.8378073,
#  ('parmigiano', 'gruyere'): 0.6899903,
#  ('parmigiano', 'gruyère'): 0.7082071,
#  ('parmigiano', 'parmigianino'): 0.71473956,
#  ('parmesan', 'romano'): 0.8591327,
#  ('parmesan', 'pecorino'): 0.80688703,
#  ('parmesan', 'gruyere'): 0.758365,
#  ('parmesan', 'gruyère'): 0.77006996,
#  ('parmesan', 'emmental'): 0.65286356,
#  ('asparagus', 'broccoli'): 0.6771777,
#  ('asparagus', 'broccolini'): 0.7620194,
#  ('broccoli', 'cauliflower'): 0.8158508,
#  ('broccoli', 'broccolini'): 0.6989232,
#  ('goat', 'feta'): 0.74357176,
#  ('goat', 'gorgonzola'): 0.75711036,
#  ('goat', 'roquefort'): 0.7437395,
#  ('goat', 'stilton'): 0.7267524,
#  ('goat', 'halloumi'): 0.6519192,
#  ('goat', 'robiola'): 0.6655946,
#  ('feta', 'gorgonzola'): 0.72148037,
#  ('feta', 'roquefort'): 0.70893925,
#  ('feta', 'stilton'): 0.6767045,
#  ('oranges', 'grapefruit'): 0.76217693,
#  ('oranges', 'tangerine'): 0.74293864,
#  ('oranges', 'grapefruits'): 0.7641563,
#  ('oranges', 'clementines'): 0.8381064,
#  ('oranges', 'clementine'): 0.7713666,
#  ('turmeric', 'coriander'): 0.78702223,
#  ('turmeric', 'tumeric'): 0.7934739,
#  ('coriander', 'fenugreek'): 0.75806624,
#  ('steaks', 'steak'): 0.83821636,
#  ('steaks', 'venison'): 0.6628578,
#  ('steaks', 'swordfish'): 0.7616319,
#  ('cardamom', 'canela'): 0.65312594,
#  ('banana', 'bananas'): 0.72120976,
#  ('bananas', 'peaches'): 0.74448884,
#  ('bananas', 'kiwis'): 0.6688263,
#  ('bananas', 'kiwifruit'): 0.6623675,
#  ('horseradish', 'mayonnaise'): 0.68088025,
#  ('mayonnaise', 'mayo'): 0.7466908,
#  ('spaghetti', 'pasta'): 0.82038826,
#  ('spaghetti', 'penne'): 0.72990805,
#  ('spaghetti', 'macaroni'): 0.67935497,
#  ('spaghetti', 'marinara'): 0.6732207,
#  ('spaghetti', 'linguine'): 0.73504466,
#  ('spaghetti', 'fettuccine'): 0.6922969,
#  ('spaghetti', 'linguini'): 0.66985756,
#  ('pasta', 'penne'): 0.76961136,
#  ('pasta', 'macaroni'): 0.7285785,
#  ('pasta', 'linguine'): 0.82017034,
#  ('pasta', 'fettuccine'): 0.8001592,
#  ('pasta', 'tortellini'): 0.70073,
#  ('pasta', 'ravioli'): 0.6863065,
#  ('pasta', 'linguini'): 0.699329,
#  ('pasta', 'fettuccini'): 0.67484885,
#  ('pasta', 'fettucine'): 0.662044,
#  ('panko', 'breadcrumbs'): 0.81431574,
#  ('rib', 'ribs'): 0.75421524,
#  ('ribs', 'brisket'): 0.6896276,
#  ('peaches', 'apples'): 0.68390197,
#  ('peaches', 'berries'): 0.6585694,
#  ('peaches', 'pears'): 0.7677014,
#  ('peaches', 'apricots'): 0.65731055,
#  ('peaches', 'peach'): 0.6855346,
#  ('peaches', 'blackberries'): 0.691646,
#  ('peaches', 'pear'): 0.6554435,
#  ('peaches', 'plums'): 0.8317601,
#  ('peaches', 'rhubarb'): 0.6817817,
#  ('peaches', 'mangoes'): 0.73244226,
#  ('peaches', 'nectarines'): 0.8366832,
#  ('peaches', 'mangos'): 0.6755031,
#  ('peaches', 'persimmons'): 0.65663964,
#  ('peaches', 'nectarine'): 0.682666,
#  ('apples', 'pears'): 0.82242155,
#  ('apples', 'plums'): 0.6691896,
#  ('grape', 'cherry'): 0.6847944,
#  ('raspberry', 'apricot'): 0.7634105,
#  ('raspberry', 'strawberry'): 0.8572928,
#  ('raspberry', 'berry'): 0.7550144,
#  ('raspberry', 'blueberry'): 0.8195917,
#  ('raspberry', 'guava'): 0.6911878,
#  ('raspberry', 'blackberry'): 0.8630799,
#  ('raspberry', 'boysenberry'): 0.66009605,
#  ('raspberry', 'passionfruit'): 0.6674876,
#  ('shiitake', 'mushrooms'): 0.6510357,
#  ('shiitake', 'portobello'): 0.74367386,
#  ('shiitake', 'porcini'): 0.67887217,
#  ('veal', 'venison'): 0.74910843,
#  ('veal', 'shanks'): 0.663939,
#  ('veal', 'rabbit'): 0.7302743,
#  ('baguette', 'bread'): 0.7250209,
#  ('baguette', 'brioche'): 0.7467101,
#  ('baguette', 'ciabatta'): 0.76422054,
#  ('baguette', 'focaccia'): 0.7466856,
#  ('baguette', 'baguettes'): 0.807289,
#  ('bread', 'brioche'): 0.65537286,
#  ('bread', 'cornflake'): 0.7215916,
#  ('berries', 'blackberries'): 0.7845877,
#  ('berries', 'rhubarb'): 0.6629963,
#  ('tartar', 'sour'): 0.66021645,
#  ('cauliflower', 'romanesco'): 0.66147405,
#  ('pears', 'pear'): 0.705629,
#  ('pears', 'figs'): 0.7061409,
#  ('pears', 'plums'): 0.7391101,
#  ('pears', 'rhubarb'): 0.6558643,
#  ('romano', 'pecorino'): 0.908895,
#  ('romano', 'gruyere'): 0.725557,
#  ('romano', 'gruyère'): 0.74613035,
#  ('romano', 'emmentaler'): 0.65034,
#  ('romano', 'emmental'): 0.7050788,
#  ('romano', 'comté'): 0.6837942,
#  ('romano', 'edam'): 0.6700645,
#  ('romano', 'parmigianino'): 0.688096,
#  ('grapeseed', 'safflower'): 0.7176768,
#  ('scallion', 'scallions'): 0.8302203,
#  ('fillet', 'cod'): 0.6746189,
#  ('fillet', 'snapper'): 0.6679862,
#  ('fillet', 'trout'): 0.7416085,
#  ('fillet', 'tilapia'): 0.7278613,
#  ('fillet', 'sole'): 0.8061057,
#  ('fillet', 'monkfish'): 0.7269505,
#  ('fillet', 'whitefish'): 0.7150954,
#  ('fillet', 'rockfish'): 0.67275363,
#  ('fillet', 'seabass'): 0.71419454,
#  ('fillet', 'sardine'): 0.65839785,
#  ('preserves', 'jam'): 0.9128685,
#  ('avocados', 'mangoes'): 0.72387904,
#  ('avocados', 'mangos'): 0.7354147,
#  ('avocados', 'persimmons'): 0.6773624,
#  ('avocados', 'avocadoes'): 0.7777155,
#  ('loin', 'shoulder'): 0.8446345,
#  ('loin', 'tenderloin'): 0.86392695,
#  ('loin', 'tenderloins'): 0.7947679,
#  ('loin', 'venison'): 0.67630166,
#  ('loin', 'shank'): 0.7443489,
#  ('loin', 'spareribs'): 0.70083356,
#  ('shoulder', 'tenderloin'): 0.75773066,
#  ('shoulder', 'tenderloins'): 0.74068975,
#  ('shoulder', 'shank'): 0.767239,
#  ('shoulder', 'spareribs'): 0.7598954,
#  ('espresso', 'cocoa'): 0.70815897,
#  ('espresso', 'coffee'): 0.8410292,
#  ('espresso', 'kahlúa'): 0.65420926,
#  ('coffee', 'kahlua'): 0.66473955,
#  ('coffee', 'kahlúa'): 0.6549727,
#  ('cracker', 'crackers'): 0.65180016,
#  ('cracker', 'cornflake'): 0.756885,
#  ('crackers', 'saltines'): 0.66286916,
#  ('scallops', 'shrimp'): 0.7016531,
#  ('scallops', 'prawns'): 0.7269579,
#  ('scallops', 'shrimps'): 0.6818981,
#  ('shrimp', 'squid'): 0.6729682,
#  ('shrimp', 'prawns'): 0.8627139,
#  ('shrimp', 'crawfish'): 0.6844032,
#  ('shrimp', 'calamari'): 0.65166366,
#  ('shrimp', 'shrimps'): 0.7090344,
#  ('eggplant', 'eggplants'): 0.81763154,
#  ('tenderloin', 'tenderloins'): 0.8487036,
#  ('tenderloin', 'venison'): 0.72482455,
#  ('tenderloin', 'shank'): 0.71489984,
#  ('tenderloin', 'spareribs'): 0.68717796,
#  ('tenderloin', 'elk'): 0.67310214,
#  ('hazelnuts', 'pistachios'): 0.83589137,
#  ('hazelnuts', 'cashews'): 0.6776303,
#  ('hazelnuts', 'pinenuts'): 0.6718823,
#  ('apricots', 'dates'): 0.7279177,
#  ('apricots', 'figs'): 0.8354007,
#  ('apricots', 'currants'): 0.7380534,
#  ('apricots', 'plums'): 0.723571,
#  ('apricots', 'prunes'): 0.77508116,
#  ('apricot', 'strawberry'): 0.68252814,
#  ('apricot', 'peach'): 0.75159127,
#  ('apricot', 'blueberry'): 0.66180384,
#  ('apricot', 'guava'): 0.72264695,
#  ('apricot', 'blackberry'): 0.7946589,
#  ('pecorino', 'gruyere'): 0.74160975,
#  ('pecorino', 'gruyère'): 0.7355192,
#  ('pecorino', 'emmental'): 0.7084795,
#  ('pecorino', 'comté'): 0.6697346,
#  ('pecorino', 'parmigianino'): 0.7205127,
#  ('strawberry', 'peach'): 0.7242535,
#  ('strawberry', 'berry'): 0.82348865,
#  ('strawberry', 'blueberry'): 0.8546412,
#  ('strawberry', 'blackberry'): 0.8502703,
#  ('strawberry', 'boysenberry'): 0.6949084,
#  ('strawberry', 'passionfruit'): 0.66734856,
#  ('cucumbers', 'cucumber'): 0.8632859,
#  ('cucumbers', 'radishes'): 0.71535164,
#  ('cucumber', 'radishes'): 0.6832235,
#  ('cucumber', 'radish'): 0.7505094,
#  ('tortilla', 'tortillas'): 0.7438496,
#  ('watercress', 'radishes'): 0.65203696,
#  ('watercress', 'radicchio'): 0.6714755,
#  ('watercress', 'endive'): 0.65908384,
#  ('watercress', 'lettuces'): 0.6510652,
#  ('mascarpone', 'ricotta'): 0.6974878,
#  ('ricotta', 'cottage'): 0.72464746,
#  ('pancetta', 'bacon'): 0.78431773,
#  ('pancetta', 'prosciutto'): 0.7341486,
#  ('prosciutto', 'salami'): 0.7560116,
#  ('prosciutto', 'pepperoni'): 0.659469,
#  ('prosciutto', 'proscuitto'): 0.75560284,
#  ('radishes', 'radish'): 0.7132261,
#  ('tequila', 'gin'): 0.65703183,
#  ('peach', 'pear'): 0.77005845,
#  ('peach', 'berry'): 0.6781356,
#  ('peach', 'blueberry'): 0.6562637,
#  ('peach', 'guava'): 0.70576984,
#  ('peach', 'blackberry'): 0.7204248,
#  ('peach', 'nectarine'): 0.8299575,
#  ('chorizo', 'sausage'): 0.8232845,
#  ('chorizo', 'sausages'): 0.69316906,
#  ('chorizo', 'kielbasa'): 0.6765122,
#  ('sausage', 'sausages'): 0.773567,
#  ('sausage', 'kielbasa'): 0.7210655,
#  ('jalapeño', 'jalapenos'): 0.8006365,
#  ('jalapeño', 'habanero'): 0.7883951,
#  ('jalapeño', 'jalapeños'): 0.78201693,
#  ('jalapeño', 'jalepeno'): 0.7407026,
#  ('jalapeño', 'serranos'): 0.7415289,
#  ('blackberries', 'rhubarb'): 0.7474825,
#  ('blackberries', 'nectarines'): 0.65514404,
#  ('blackberries', 'gooseberries'): 0.6616739,
#  ('chilies', 'jalapenos'): 0.6750052,
#  ('chilies', 'chipotles'): 0.66635823,
#  ('chilies', 'jalapeños'): 0.74662715,
#  ('gin', 'champagne'): 0.67822826,
#  ('gin', 'vermouth'): 0.6690165,
#  ('gin', 'seltzer'): 0.6738867,
#  ('gin', 'lemonade'): 0.7062712,
#  ('gin', 'prosecco'): 0.7398693,
#  ('gin', 'drink'): 0.6551618,
#  ('gin', 'limoncello'): 0.68712133,
#  ('gin', 'hendricks'): 0.79542863,
#  ('gin', 'claret'): 0.6566475,
#  ('champagne', 'prosecco'): 0.7900714,
#  ('vermouth', 'wine'): 0.66675603,
#  ('grapefruit', 'tangerine'): 0.81368744,
#  ('grapefruit', 'grapefruits'): 0.80554307,
#  ('grapefruit', 'clementines'): 0.67353654,
#  ('grapefruit', 'clementine'): 0.8437779,
#  ('pear', 'nectarine'): 0.7924544,
#  ('penne', 'linguine'): 0.8687298,
#  ('penne', 'fettuccine'): 0.8313539,
#  ('penne', 'rotini'): 0.8914548,
#  ('penne', 'fusilli'): 0.9040457,
#  ('penne', 'linguini'): 0.84650725,
#  ('penne', 'pappardelle'): 0.8253759,
#  ('penne', 'tagliatelle'): 0.7144289,
#  ('penne', 'fettuccini'): 0.8641796,
#  ('penne', 'seashell'): 0.6919205,
#  ('penne', 'spaghettini'): 0.76879776,
#  ('penne', 'barilla'): 0.74798936,
#  ('penne', 'fettucine'): 0.69908965,
#  ('penne', 'perciatelli'): 0.7163159,
#  ('dates', 'currants'): 0.690932,
#  ('dates', 'prunes'): 0.7439079,
#  ('cookie', 'cookies'): 0.6851543,
#  ('cookies', 'shortbread'): 0.6752023,
#  ('cookies', 'biscotti'): 0.72039056,
#  ('pistachios', 'peanuts'): 0.65274477,
#  ('pistachios', 'cashews'): 0.7739217,
#  ('peanuts', 'cashews'): 0.8097827,
#  ('jalapenos', 'jalapeños'): 0.8776926,
#  ('jalapenos', 'serranos'): 0.77627504,
#  ('macaroni', 'tortellini'): 0.66426784,
#  ('tabasco', 'worcestershire'): 0.67164224,
#  ('tabasco', 'tabasco®'): 0.7967309,
#  ('lentils', 'chickpeas'): 0.7092037,
#  ('lentils', 'quinoa'): 0.6929966,
#  ('lentils', 'barley'): 0.7450029,
#  ('crab', 'crabmeat'): 0.7039357,
#  ('crab', 'lobster'): 0.6610046,
#  ('gruyere', 'cheddar'): 0.73981684,
#  ('gruyere', 'provolone'): 0.72230905,
#  ('gruyere', 'gouda'): 0.806675,
#  ('gruyere', 'gruyère'): 0.9086188,
#  ('gruyere', 'havarti'): 0.7636405,
#  ('gruyere', 'emmentaler'): 0.84012467,
#  ('gruyere', 'comte'): 0.7247418,
#  ('gruyere', 'emmental'): 0.84590995,
#  ('gruyere', 'emmenthal'): 0.82529986,
#  ('gruyere', 'comté'): 0.73977554,
#  ('gruyere', 'edam'): 0.7402652,
#  ('gruyere', 'parmigianino'): 0.6755118,
#  ('cheddar', 'provolone'): 0.65445405,
#  ('cheddar', 'gouda'): 0.6819216,
#  ('cheddar', 'gruyère'): 0.7121129,
#  ('cheddar', 'emmentaler'): 0.68357205,
#  ('cheddar', 'emmenthal'): 0.6581557,
#  ('walnut', 'pecan'): 0.7774796,
#  ('lobster', 'lobsters'): 0.7042361,
#  ('lobster', 'crawfish'): 0.7665173,
#  ('lobster', 'crayfish'): 0.67144734,
#  ('tart', 'pie'): 0.69674045,
#  ('pie', 'piecrust'): 0.68166476,
#  ('portobello', 'portobellos'): 0.6959459,
#  ('agave', 'maple'): 0.6502109,
#  ('provolone', 'mozzarella'): 0.7532847,
#  ('provolone', 'american'): 0.7729614,
#  ('provolone', 'salami'): 0.7597452,
#  ('provolone', 'pepperoni'): 0.7425493,
#  ('provolone', 'brie'): 0.71554935,
#  ('provolone', 'gouda'): 0.7321821,
#  ('provolone', 'gruyère'): 0.7031773,
#  ('provolone', 'havarti'): 0.8189904,
#  ('provolone', 'emmentaler'): 0.6678093,
#  ('provolone', 'halloumi'): 0.7018213,
#  ('provolone', 'emmental'): 0.66377676,
#  ('provolone', 'robiola'): 0.66370773,
#  ('provolone', 'emmenthal'): 0.70312625,
#  ('mozzarella', 'pepperoni'): 0.67458683,
#  ('mozzarella', 'gouda'): 0.6515161,
#  ('whiskey', 'schnapps'): 0.653887,
#  ('whiskey', 'cola'): 0.66938823,
#  ('whiskey', 'applejack'): 0.76089114,
#  ('hamburger', 'buns'): 0.78813654,
#  ('hamburger', 'burger'): 0.76055825,
#  ('buns', 'pitas'): 0.650687,
#  ('buns', 'burger'): 0.714181,
#  ('buns', 'baguettes'): 0.6668089,
#  ('figs', 'plums'): 0.7132648,
#  ('figs', 'prunes'): 0.68211114,
#  ('quinoa', 'couscous'): 0.73763674,
#  ('quinoa', 'barley'): 0.7145238,
#  ('quinoa', 'bulgur'): 0.74537486,
#  ('couscous', 'bulgur'): 0.7713318,
#  ('cannellini', 'kidney'): 0.80094016,
#  ('cannellini', 'garbanzo'): 0.8048749,
#  ('cannellini', 'cannelini'): 0.82201695,
#  ('kidney', 'garbanzo'): 0.69742703,
#  ('kidney', 'cannelini'): 0.7529525,
#  ('watermelon', 'melon'): 0.7468377,
#  ('watermelon', 'papaya'): 0.67225814,
#  ('watermelon', 'mangoes'): 0.67002666,
#  ('watermelon', 'cantaloupe'): 0.88740855,
#  ('watermelon', 'honeydew'): 0.78024536,
#  ('watermelon', 'cantaloupes'): 0.6610124,
#  ('cod', 'snapper'): 0.66403514,
#  ('cod', 'trout'): 0.7190665,
#  ('cod', 'tilapia'): 0.72864974,
#  ('cod', 'sole'): 0.77831334,
#  ('cod', 'monkfish'): 0.7659537,
#  ('cod', 'whitefish'): 0.76004064,
#  ('cod', 'rockfish'): 0.68138146,
#  ('cod', 'seabass'): 0.66608715,
#  ('rye', 'sourdough'): 0.65300834,
#  ('rye', 'pumpernickel'): 0.6876695,
#  ('sourdough', 'brioche'): 0.69167054,
#  ('sourdough', 'ciabatta'): 0.781109,
#  ('sourdough', 'pumpernickel'): 0.7800838,
#  ('sourdough', 'focaccia'): 0.69582844,
#  ('mussels', 'clams'): 0.91371316,
#  ('mussels', 'shellfish'): 0.7981465,
#  ('clams', 'oysters'): 0.701685,
#  ('clams', 'shellfish'): 0.7668336,
#  ('garbanzo', 'cannelini'): 0.7146199,
#  ('american', 'havarti'): 0.73794514,
#  ('american', 'emmenthal'): 0.6546884,
#  ('habanero', 'chipotle'): 0.71155566,
#  ('habanero', 'jalepeno'): 0.7312645,
#  ('chipotle', 'chipotles'): 0.80051994,
#  ('chipotle', 'chipolte'): 0.6659525,
#  ('currants', 'raisins'): 0.7120671,
#  ('currants', 'prunes'): 0.6652163,
#  ('pickles', 'pickle'): 0.78481495,
#  ('caraway', 'sunflower'): 0.76025385,
#  ('caraway', 'poppy'): 0.87013406,
#  ('sunflower', 'poppy'): 0.78851587,
#  ('parsnips', 'turnips'): 0.89494276,
#  ('parsnips', 'yams'): 0.6565998,
#  ('parsnips', 'turnip'): 0.7250158,
#  ('parsnips', 'parsnip'): 0.7519584,
#  ('parsnips', 'rutabaga'): 0.84561235,
#  ('parsnips', 'rutabagas'): 0.81049776,
#  ('marinara', 'enchilada'): 0.70285815,
#  ('marinara', 'picante'): 0.7181116,
#  ('marinara', 'bechamel'): 0.7156218,
#  ('marinara', 'bolognese'): 0.71510494,
#  ('linguine', 'fettuccine'): 0.8566612,
#  ('linguine', 'rotini'): 0.7706233,
#  ('linguine', 'fusilli'): 0.76974934,
#  ('linguine', 'tortellini'): 0.6562852,
#  ('linguine', 'linguini'): 0.8167414,
#  ('linguine', 'pappardelle'): 0.73352873,
#  ('linguine', 'tagliatelle'): 0.68064505,
#  ('linguine', 'fettuccini'): 0.79448473,
#  ('linguine', 'spaghettini'): 0.75753576,
#  ('linguine', 'barilla'): 0.658973,
#  ('linguine', 'fettucine'): 0.66426826,
#  ('radicchio', 'endive'): 0.8595319,
#  ('radicchio', 'lettuces'): 0.74024117,
#  ('gorgonzola', 'roquefort'): 0.8671946,
#  ('gorgonzola', 'stilton'): 0.8804778,
#  ('plums', 'nectarines'): 0.8381178,
#  ('plums', 'nectarine'): 0.66088796,
#  ('sausages', 'kielbasa'): 0.7455074,
#  ('snapper', 'trout'): 0.67552274,
#  ('snapper', 'tilapia'): 0.69486827,
#  ('snapper', 'sole'): 0.7234567,
#  ('snapper', 'monkfish'): 0.7392346,
#  ('snapper', 'whitefish'): 0.66744393,
#  ('snapper', 'rockfish'): 0.6843844,
#  ('snapper', 'seabass'): 0.70222104,
#  ('artichokes', 'artichoke'): 0.77629036,
#  ('brioche', 'ciabatta'): 0.831636,
#  ('brioche', 'pumpernickel'): 0.65687233,
#  ('brioche', 'focaccia'): 0.71550506,
#  ('brioche', 'baguettes'): 0.72184396,
#  ('brioche', 'panettone'): 0.7231511,
#  ('endive', 'lettuces'): 0.7649469,
#  ('melon', 'cantaloupe'): 0.823334,
#  ('melon', 'honeydew'): 0.7786707,
#  ('melon', 'cantaloupes'): 0.6680467,
#  ('turnips', 'beets'): 0.6890556,
#  ('turnips', 'turnip'): 0.7881681,
#  ('turnips', 'parsnip'): 0.6789617,
#  ('turnips', 'rutabaga'): 0.79641455,
#  ('turnips', 'rutabagas'): 0.7943017,
#  ('sambal', 'sriracha'): 0.824353,
#  ('ciabatta', 'sandwich'): 0.6545828,
#  ('ciabatta', 'pumpernickel'): 0.71140265,
#  ('ciabatta', 'focaccia'): 0.8733756,
#  ('ciabatta', 'baguettes'): 0.7904194,
#  ('salami', 'pepperoni'): 0.83383936,
#  ('salami', 'parma'): 0.67797166,
#  ('salami', 'pastrami'): 0.6897052,
#  ('salami', 'proscuitto'): 0.71883214,
#  ('pepperoni', 'pastrami'): 0.66446626,
#  ('barley', 'bulgur'): 0.7122205,
#  ('papaya', 'mangoes'): 0.79970044,
#  ('papaya', 'cantaloupe'): 0.73228055,
#  ('papaya', 'kiwi'): 0.66979975,
#  ('papaya', 'mangos'): 0.75540346,
#  ('papaya', 'kiwis'): 0.67829174,
#  ('papaya', 'persimmons'): 0.6587489,
#  ('papaya', 'papayas'): 0.7252338,
#  ('fettuccine', 'rotini'): 0.74764687,
#  ('fettuccine', 'fusilli'): 0.76210594,
#  ('fettuccine', 'tortellini'): 0.6854758,
#  ('fettuccine', 'linguini'): 0.794783,
#  ('fettuccine', 'pappardelle'): 0.76240236,
#  ('fettuccine', 'tagliatelle'): 0.8154288,
#  ('fettuccine', 'fettuccini'): 0.84576815,
#  ('fettuccine', 'spaghettini'): 0.6892038,
#  ('fettuccine', 'barilla'): 0.6822401,
#  ('fettuccine', 'fettucine'): 0.7350997,
#  ('jasmine', 'basmati'): 0.8839413,
#  ('jasmine', 'krispies'): 0.7017069,
#  ('basmati', 'krispies'): 0.7124324,
#  ('gingerroot', 'ginger'): 0.8106315,
#  ('amaretto', 'limoncello'): 0.7069224,
#  ('amaretto', 'kahlua'): 0.7165147,
#  ('amaretto', 'frangelico'): 0.81461984,
#  ('amaretto', 'sambuca'): 0.6808397,
#  ('amaretto', 'blackcurrant'): 0.6602263,
#  ('seltzer', 'prosecco'): 0.6974929,
#  ('lemonade', 'prosecco'): 0.6850935,
#  ('lemonade', 'drink'): 0.68668836,
#  ('lemonade', 'limoncello'): 0.65408504,
#  ('lemonade', 'margarita'): 0.6834408,
#  ('lemonade', 'hendricks'): 0.6539951,
#  ('anchovies', 'capers'): 0.7187342,
#  ('anchovies', 'anchovy'): 0.65485424,
#  ('skirt', 'sirloin'): 0.6944249,
#  ('skirt', 'porterhouse'): 0.8439265,
#  ('skirt', 'ribeye'): 0.7119807,
#  ('sirloin', 'bison'): 0.75078654,
#  ('sirloin', 'porterhouse'): 0.6654046,
#  ('sirloin', 'elk'): 0.7142333,
#  ('sirloin', 'ribeye'): 0.71187615,
#  ('lobsters', 'crabs'): 0.7725591,
#  ('lobsters', 'crawfish'): 0.67211705,
#  ('lobsters', 'octopus'): 0.6583352,
#  ('lobsters', 'crayfish'): 0.6708033,
#  ('trout', 'tilapia'): 0.7656369,
#  ('trout', 'sole'): 0.7843314,
#  ('trout', 'monkfish'): 0.72949374,
#  ('trout', 'whitefish'): 0.7935312,
#  ('trout', 'rockfish'): 0.7234564,
#  ('trout', 'seabass'): 0.67536753,
#  ('mangoes', 'cantaloupe'): 0.74717367,
#  ('mangoes', 'nectarines'): 0.6824927,
#  ('mangoes', 'kiwi'): 0.6981396,
#  ('mangoes', 'mangos'): 0.877883,
#  ('mangoes', 'kiwis'): 0.78122586,
#  ('mangoes', 'persimmons'): 0.76523936,
#  ('mangoes', 'papayas'): 0.80166405,
#  ('mangoes', 'cantaloupes'): 0.6883392,
#  ('mangoes', 'kiwifruit'): 0.71887594,
#  ('mangoes', 'avocadoes'): 0.6554682,
#  ('cantaloupe', 'honeydew'): 0.8692108,
#  ('cantaloupe', 'kiwi'): 0.7036032,
#  ('cantaloupe', 'mangos'): 0.72163665,
#  ('cantaloupe', 'kiwis'): 0.672866,
#  ('cantaloupe', 'persimmons'): 0.6644632,
#  ('cantaloupe', 'cantaloupes'): 0.7517139,
#  ('butterflied', 'tail'): 0.6739605,
#  ('tail', 'muscle'): 0.6537856,
#  ('tail', 'prawn'): 0.66062325,
#  ('tail', 'tomalley'): 0.69709074,
#  ('fudge', 'caramel'): 0.6661335,
#  ('fudge', 'brownie'): 0.65487605,
#  ('fudge', 'ganache'): 0.69757617,
#  ('schnapps', 'applejack'): 0.6764804,
#  ('tenderloins', 'venison'): 0.6616271,
#  ('tenderloins', 'spareribs'): 0.73922294,
#  ('crema', 'salsa'): 0.66962355,
#  ('crema', 'guacamole'): 0.7454652,
#  ('salsa', 'guacamole'): 0.8016594,
#  ('squid', 'prawns'): 0.74270844,
#  ('squid', 'calamari'): 0.8794005,
#  ('squid', 'octopus'): 0.6577761,
#  ('squid', 'shrimps'): 0.6797061,
#  ('squid', 'cuttlefish'): 0.65369654,
#  ('beefsteak', 'plum'): 0.667058,
#  ('brie', 'havarti'): 0.69640017,
#  ('brie', 'camembert'): 0.80984867,
#  ('brie', 'halloumi'): 0.7009206,
#  ('brie', 'robiola'): 0.67221063,
#  ('biscuit', 'biscuits'): 0.7088171,
#  ('biscuits', 'scones'): 0.7884962,
#  ('gouda', 'gruyère'): 0.79776824,
#  ('gouda', 'havarti'): 0.7909266,
#  ('gouda', 'emmentaler'): 0.7617845,
#  ('gouda', 'comte'): 0.6824845,
#  ('gouda', 'emmental'): 0.74444515,
#  ('gouda', 'emmenthal'): 0.7724245,
#  ('gouda', 'comté'): 0.7135485,
#  ('gouda', 'edam'): 0.7251727,
#  ('wafers', 'wafer'): 0.8232272,
#  ('wafer', 'gingersnap'): 0.72442305,
#  ('wafer', 'amaretti'): 0.6965476,
#  ('wafer', 'oreo'): 0.7052576,
#  ('wafer', 'oreo®'): 0.7360663,
#  ('edamame', 'peas'): 0.6767206,
#  ('edamame', 'soybeans'): 0.80983317,
#  ('drumsticks', 'breast'): 0.693468,
#  ('drumsticks', 'wings'): 0.7934091,
#  ('drumsticks', 'chickens'): 0.7203126,
#  ('drumsticks', 'tenders'): 0.72716534,
#  ('drumsticks', 'ducks'): 0.65069014,
#  ('drumsticks', 'drumstick'): 0.665359,
#  ('drumsticks', 'guinea'): 0.7258662,
#  ('breast', 'tenders'): 0.6758485,
#  ('wings', 'tenders'): 0.6766908,
#  ('chickens', 'goose'): 0.6776415,
#  ('chickens', 'ducks'): 0.80710363,
#  ('chickens', 'pheasants'): 0.6720595,
#  ('tangerine', 'clementines'): 0.66645634,
#  ('tangerine', 'clementine'): 0.8855823,
#  ('lager', 'beer'): 0.7275941,
#  ('lager', 'guinness'): 0.80008066,
#  ('lager', 'pilsner'): 0.87095153,
#  ('lager', 'beers'): 0.7345569,
#  ('lager', 'ipa'): 0.8122546,
#  ('lager', 'budweiser'): 0.82528025,
#  ('beer', 'guinness'): 0.7133565,
#  ('pistachio', 'macadamia'): 0.7804555,
#  ('pistachio', 'nut'): 0.66732705,
#  ('pistachio', 'cashew'): 0.75392896,
#  ('macadamia', 'cashew'): 0.7578585,
#  ('tenders', 'rotisserie'): 0.71547216,
#  ('tenders', 'livers'): 0.6590137,
#  ('honeydew', 'kiwi'): 0.6852269,
#  ('berry', 'cranberry'): 0.65242404,
#  ('berry', 'blueberry'): 0.8490257,
#  ('berry', 'blackberry'): 0.83111316,
#  ('berry', 'boysenberry'): 0.664687,
#  ('cranberry', 'blueberry'): 0.6675748,
#  ('cranberry', 'blackberry'): 0.6736298,
#  ('yams', 'rutabagas'): 0.65989614,
#  ('tilapia', 'swordfish'): 0.6621423,
#  ('tilapia', 'sole'): 0.87065583,
#  ('tilapia', 'monkfish'): 0.8324151,
#  ('tilapia', 'whitefish'): 0.7454224,
#  ('tilapia', 'rockfish'): 0.80589837,
#  ('tilapia', 'seabass'): 0.819053,
#  ('tilapia', 'sardine'): 0.65321696,
#  ('muffins', 'muffin'): 0.66070825,
#  ('venison', 'rabbit'): 0.66652817,
#  ('venison', 'bison'): 0.68937606,
#  ('venison', 'elk'): 0.8029206,
#  ('turnip', 'parsnip'): 0.7836413,
#  ('turnip', 'rutabaga'): 0.7596957,
#  ('turnip', 'rutabagas'): 0.72285014,
#  ('pretzels', 'pretzel'): 0.77638996,
#  ('pretzel', 'butterfinger®'): 0.6673203,
#  ('prawns', 'crabs'): 0.690888,
#  ('prawns', 'crawfish'): 0.66425556,
#  ('prawns', 'calamari'): 0.7341544,
#  ('prawns', 'octopus'): 0.673643,
#  ('prawns', 'shrimps'): 0.8019484,
#  ('prawns', 'cuttlefish'): 0.65176845,
#  ('brownie', 'cake'): 0.7196319,
#  ('brownie', 'brownies'): 0.6627977,
#  ('cake', 'cheesecake'): 0.6696147,
#  ('liver', 'giblets'): 0.6632961,
#  ('liver', 'livers'): 0.7566038,
#  ('gruyère', 'havarti'): 0.7457854,
#  ('gruyère', 'emmentaler'): 0.8191509,
#  ('gruyère', 'comte'): 0.7542536,
#  ('gruyère', 'emmental'): 0.84901786,
#  ('gruyère', 'kefalotyri'): 0.73113894,
#  ('gruyère', 'emmenthal'): 0.86464775,
#  ('gruyère', 'comté'): 0.80500335,
#  ('gruyère', 'edam'): 0.7737677,
#  ('gruyère', 'emmenthaler'): 0.6724667,
#  ('gruyère', 'gruyére'): 0.6640766,
#  ('gruyère', 'parmigianino'): 0.7173171,
#  ('shanks', 'shank'): 0.6744678,
#  ('blueberry', 'blackberry'): 0.84604055,
#  ('blueberry', 'boysenberry'): 0.73955154,
#  ('prosecco', 'drink'): 0.6730354,
#  ('prosecco', 'limoncello'): 0.6549194,
#  ('prosecco', 'rosé'): 0.7539711,
#  ('prosecco', 'claret'): 0.6545729,
#  ('rotini', 'fusilli'): 0.91768783,
#  ('rotini', 'linguini'): 0.78674626,
#  ('rotini', 'pappardelle'): 0.8147671,
#  ('rotini', 'tagliatelle'): 0.6678675,
#  ('rotini', 'fettuccini'): 0.8446177,
#  ('rotini', 'seashell'): 0.7773744,
#  ('rotini', 'spaghettini'): 0.78545445,
#  ('rotini', 'barilla'): 0.7093442,
#  ('rotini', 'perciatelli'): 0.7244752,
#  ('pepperoncini', 'pimento'): 0.8010685,
#  ('pepperoncini', 'pimiento'): 0.72662157,
#  ('pepperoncini', 'jalapeños'): 0.6696091,
#  ('pepperoncini', 'peperoncini'): 0.77056116,
#  ('pepperoncini', 'peppadews'): 0.66549635,
#  ('pimento', 'pimiento'): 0.79941493,
#  ('pimento', 'peperoncini'): 0.66055113,
#  ('harissa', 'tahini'): 0.71103644,
#  ('madeira', 'marsala'): 0.77686477,
#  ('marsala', 'merlot'): 0.7101935,
#  ('nectarines', 'nectarine'): 0.7100728,
#  ('nicoise', 'kalamata'): 0.896305,
#  ('nicoise', 'calamata'): 0.87468994,
#  ('kalamata', 'calamata'): 0.8813512,
#  ('safflower', 'groundnut'): 0.6653713,
#  ('pumpernickel', 'focaccia'): 0.6540195,
#  ('kiwi', 'mangos'): 0.69446385,
#  ('kiwi', 'kiwis'): 0.84453297,
#  ('kiwi', 'kiwifruit'): 0.7491578,
#  ('swordfish', 'monkfish'): 0.6826855,
#  ('swordfish', 'porterhouse'): 0.7139328,
#  ('enchilada', 'picante'): 0.8022557,
#  ('guava', 'tamarind'): 0.68480456,
#  ('guava', 'blackberry'): 0.6617057,
#  ('tabasco®', 'franks'): 0.7432237,
#  ('drink', 'margarita'): 0.7036553,
#  ('drink', 'rosé'): 0.6567366,
#  ('drink', 'claret'): 0.7234032,
#  ('shank', 'spareribs'): 0.66948545,
#  ('crabs', 'crawfish'): 0.73879224,
#  ('fusilli', 'linguini'): 0.8309262,
#  ('fusilli', 'pappardelle'): 0.8468688,
#  ('fusilli', 'tagliatelle'): 0.7049578,
#  ('fusilli', 'fettuccini'): 0.8652817,
#  ('fusilli', 'seashell'): 0.79090285,
#  ('fusilli', 'spaghettini'): 0.77625406,
#  ('fusilli', 'barilla'): 0.6913331,
#  ('fusilli', 'fettucine'): 0.65542156,
#  ('fusilli', 'perciatelli'): 0.80787057,
#  ('crawfish', 'shellfish'): 0.68958247,
#  ('crawfish', 'crayfish'): 0.7250936,
#  ('blackberry', 'boysenberry'): 0.7091866,
#  ('blackberry', 'passionfruit'): 0.65474373,
#  ('arrowroot', 'cornstarch'): 0.67683536,
#  ('tortellini', 'ravioli'): 0.6985181,
#  ('tortellini', 'linguini'): 0.6524314,
#  ('sole', 'monkfish'): 0.8242581,
#  ('sole', 'whitefish'): 0.76394784,
#  ('sole', 'rockfish'): 0.826584,
#  ('sole', 'seabass'): 0.81566143,
#  ('sole', 'sardine'): 0.70326877,
#  ('parsnip', 'rutabaga'): 0.78406554,
#  ('parsnip', 'rutabagas'): 0.713833,
#  ('pitas', 'pita'): 0.74054354,
#  ('pitas', 'breads'): 0.7826043,
#  ('pitas', 'baguettes'): 0.67724454,
#  ('pitas', 'flatbread'): 0.7499013,
#  ('pita', 'naan'): 0.73499846,
#  ('pita', 'flatbread'): 0.7220741,
#  ('breads', 'focaccia'): 0.6609878,
#  ('breads', 'baguettes'): 0.71181047,
#  ('breads', 'flatbread'): 0.7342721,
#  ('burger', 'patty'): 0.7852931,
#  ('grapefruits', 'clementines'): 0.68215173,
#  ('mangos', 'kiwis'): 0.8095949,
#  ('mangos', 'persimmons'): 0.78692967,
#  ('mangos', 'papayas'): 0.7776454,
#  ('mangos', 'cantaloupes'): 0.65877175,
#  ('mangos', 'kiwifruit'): 0.7285146,
#  ('mangos', 'avocadoes'): 0.6771195,
#  ('ravioli', 'gnocchi'): 0.84805864,
#  ('ravioli', 'dumplings'): 0.6746079,
#  ('roquefort', 'stilton'): 0.91825086,
#  ('roquefort', 'camembert'): 0.65365744,
#  ('calamari', 'shrimps'): 0.6703087,
#  ('focaccia', 'baguettes'): 0.7510251,
#  ('focaccia', 'naan'): 0.6651933,
#  ('focaccia', 'flatbread'): 0.70020807,
#  ('focaccia', 'crostini'): 0.6708828,
#  ('focaccia', 'foccacia'): 0.6559588,
#  ('kiwis', 'persimmons'): 0.6978127,
#  ('kiwis', 'papayas'): 0.65465456,
#  ('kiwis', 'kiwifruit'): 0.84132254,
#  ('gingersnap', 'amaretti'): 0.7814548,
#  ('gingersnap', 'oreo'): 0.7347556,
#  ('limoncello', 'sherbet'): 0.65345234,
#  ('limoncello', 'frangelico'): 0.69425064,
#  ('hummus', 'pesto'): 0.7216526,
#  ('pesto', 'tapenade'): 0.69885373,
#  ('tapenade', 'crostini'): 0.6602494,
#  ('amaretti', 'oreo'): 0.7923612,
#  ('splenda', 'sweetener'): 0.7405508,
#  ('splenda', 'splenda®'): 0.7310049,
#  ('splenda', 'sucralose'): 0.72475994,
#  ('splenda', 'sucrolose'): 0.65090615,
#  ('sweetener', 'stevia'): 0.729984,
#  ('sweetener', 'splenda®'): 0.84183925,
#  ('sweetener', 'truvia®'): 0.7927207,
#  ('sweetener', 'sucralose'): 0.8527511,
#  ('sweetener', 'sucrolose'): 0.85718066,
#  ('rutabaga', 'rutabagas'): 0.83897394,
#  ('linguini', 'pappardelle'): 0.76952493,
#  ('linguini', 'tagliatelle'): 0.69950753,
#  ('linguini', 'fettuccini'): 0.8660247,
#  ('linguini', 'seashell'): 0.6617679,
#  ('linguini', 'spaghettini'): 0.80309373,
#  ('linguini', 'barilla'): 0.6577758,
#  ('linguini', 'fettucine'): 0.7225945,
#  ('linguini', 'perciatelli'): 0.65813726,
#  ('baguettes', 'flatbread'): 0.653307,
#  ('baguettes', 'bagels'): 0.6592875,
#  ('merlot', 'chardonnay'): 0.75439954,
#  ('merlot', 'shiraz'): 0.77092,
#  ('merlot', 'rosé'): 0.6509189,
#  ('chardonnay', 'shiraz'): 0.70313925,
#  ('chardonnay', 'rosé'): 0.6748761,
#  ('plantain', 'plantains'): 0.7907637,
#  ('ganache', 'buttercream'): 0.7055274,
#  ('ganache', 'nougat'): 0.6529632,
#  ('sherbet', 'sorbet'): 0.83140975,
#  ('sorbet', 'gelato'): 0.76178294,
#  ('kahlua', 'frangelico'): 0.76706976,
#  ('kahlua', 'kahlúa'): 0.77498025,
#  ('kahlua', 'godiva'): 0.7671327,
#  ('kahlua', 'sambuca'): 0.755334,
#  ('gnocchi', 'dumplings'): 0.6708376,
#  ('frangelico', 'sambuca'): 0.7085746,
#  ('nutella', 'hazelnut'): 0.8055282,
#  ('nutella', 'nutella®'): 0.6960759,
#  ('havarti', 'camembert'): 0.6898219,
#  ('havarti', 'emmentaler'): 0.75210017,
#  ('havarti', 'halloumi'): 0.6634473,
#  ('havarti', 'comte'): 0.74413675,
#  ('havarti', 'emmental'): 0.7157017,
#  ('havarti', 'kefalotyri'): 0.6582492,
#  ('havarti', 'emmenthal'): 0.79814243,
#  ('havarti', 'comté'): 0.6741295,
#  ('havarti', 'edam'): 0.73757344,
#  ('havarti', 'haloumi'): 0.68667585,
#  ('goose', 'ducks'): 0.79260814,
#  ('jalapeños', 'jalepeno'): 0.66755724,
#  ('jalapeños', 'serranos'): 0.7090795,
#  ('valrhona', 'lindt'): 0.65243095,
#  ('valrhona', 'hersheys'): 0.68554157,
#  ('valrhona', 'callebaut'): 0.8195331,
#  ('valrhona', 'valhrona'): 0.69785017,
#  ('lindt', 'callebaut'): 0.72119206,
#  ('lindt', 'godiva'): 0.68541914,
#  ('lindt', 'godiva®'): 0.69794196,
#  ('shortbread', 'brownies'): 0.7078471,
#  ('naan', 'flatbread'): 0.74472666,
#  ('hersheys', 'nestle®'): 0.77788216,
#  ('hersheys', 'hersheys®'): 0.67662245,
#  ('hersheys', 'callebaut'): 0.71957576,
#  ('hersheys', 'snickers'): 0.6596754,
#  ('hersheys', 'valhrona'): 0.6835894,
#  ('hersheys', 'jellybeans'): 0.6951604,
#  ('hersheys', 'starburst®'): 0.6940408,
#  ('krispies®', 'cereal'): 0.6885434,
#  ('krispies®', 'kelloggs®'): 0.91292703,
#  ('krispies®', 'krispies'): 0.79076004,
#  ('krispies®', 'kelloggs'): 0.7821989,
#  ('cereal', 'kelloggs®'): 0.6908569,
#  ('cereal', 'krispies'): 0.6708144,
#  ('cereal', 'kelloggs'): 0.71655995,
#  ('flatbread', 'crostini'): 0.7567877,
#  ('fajita', 'taco'): 0.7774951,
#  ('fajita', 'cajun'): 0.83263296,
#  ('cajun', 'blackfish'): 0.7748009,
#  ('guinness', 'pilsner'): 0.7608678,
#  ('guinness', 'ipa'): 0.6664923,
#  ...}

# %%
positions = nx.spring_layout(G)
positions
# Out:
# {'egg': array([-0.05845469, -0.90990758]),
#  'eggs': array([-0.07255968, -0.90629864]),
#  'orange': array([0.4776772 , 0.56100416]),
#  'lemon': array([0.47008324, 0.56519783]),
#  'lime': array([0.48488587, 0.58241749]),
#  'cilantro': array([0.66723812, 0.34402752]),
#  'parsley': array([0.66461629, 0.37915415]),
#  'tomato': array([-0.53419346,  0.75416052]),
#  'tomatoes': array([-0.55010027,  0.77174777]),
#  'clove': array([-0.14234589, -0.83984351]),
#  'cloves': array([-0.14739348, -0.8752625 ]),
#  'stock': array([-0.22193474, -0.9155255 ]),
#  'broth': array([-0.23802704, -0.90573269]),
#  'leaf': array([0.27920666, 0.96059728]),
#  'leaves': array([0.27300471, 0.9383657 ]),
#  'pork': array([-0.06528655,  0.35092738]),
#  'beef': array([-0.05609591,  0.38933569]),
#  'oregano': array([0.71903777, 0.40657184]),
#  'thyme': array([0.69979239, 0.39091644]),
#  'chile': array([-0.26265007, -0.01307354]),
#  'chili': array([-0.29585317, -0.02725955]),
#  'canola': array([ 0.03353336, -0.92099625]),
#  'vegetable': array([ 0.02786444, -0.9028452 ]),
#  'mint': array([0.68682802, 0.32236269]),
#  'rosemary': array([0.70775378, 0.40680137]),
#  'chives': array([0.6655817 , 0.39813179]),
#  'walnuts': array([-0.10693637,  0.74260825]),
#  'almonds': array([-0.09299102,  0.7475661 ]),
#  'jalapeno': array([-0.22082736,  0.01615535]),
#  'bell': array([-0.25808933,  0.01520686]),
#  'turkey': array([-0.42376986,  0.13938741]),
#  'chicken': array([-0.45015746,  0.16522652]),
#  'chiles': array([-0.22216335, -0.00800533]),
#  'carrot': array([0.89265168, 0.31656209]),
#  'carrots': array([0.85219467, 0.30119142]),
#  'pecans': array([-0.10090071,  0.72313434]),
#  'almond': array([0.54366219, 0.73229319]),
#  'vanilla': array([0.53564399, 0.72010958]),
#  'fish': array([0.14180742, 0.05168713]),
#  'fillets': array([0.13114099, 0.068417  ]),
#  'nuts': array([-0.10440594,  0.75842822]),
#  'potato': array([0.81281817, 0.25135526]),
#  'potatoes': array([0.78368509, 0.26403394]),
#  'squash': array([-0.69161934,  0.22528957]),
#  'zucchini': array([-0.67357302,  0.21837692]),
#  'curry': array([-0.30588078, -0.02660534]),
#  'allspice': array([ 0.51427156, -0.57419485]),
#  'cinnamon': array([ 0.47667423, -0.5437758 ]),
#  'nutmeg': array([ 0.55135614, -0.6011039 ]),
#  'lemons': array([0.49353904, 0.55762452]),
#  'tarragon': array([0.68229663, 0.39221612]),
#  'salmon': array([0.13692319, 0.06146305]),
#  'cranberries': array([ 0.22539847, -0.29637948]),
#  'cherries': array([ 0.23211196, -0.29504904]),
#  'margarine': array([0.66679734, 0.63601112]),
#  'butter': array([0.63442141, 0.6044178 ]),
#  'arugula': array([0.28328574, 0.30076277]),
#  'spinach': array([0.3170048 , 0.31767547]),
#  'limes': array([0.48628932, 0.56858307]),
#  'raspberries': array([ 0.28925139, -0.2222226 ]),
#  'strawberries': array([ 0.28739524, -0.24384254]),
#  'brandy': array([ 0.05537933, -0.37099329]),
#  'liqueur': array([ 0.02479232, -0.31200826]),
#  'rum': array([ 0.0711249 , -0.41480577]),
#  'blueberries': array([ 0.25834379, -0.25799415]),
#  'lamb': array([-0.0721654 ,  0.36307991]),
#  'vodka': array([-0.01333921, -0.35973525]),
#  'mango': array([ 0.35628617, -0.29201326]),
#  'pineapple': array([ 0.40795121, -0.30098131]),
#  'avocado': array([ 0.37800327, -0.33342415]),
#  'parmigiano': array([-0.14916542,  0.08052062]),
#  'parmesan': array([-0.1484181 ,  0.08984759]),
#  'asparagus': array([0.68049699, 0.1688813 ]),
#  'broccoli': array([0.65525097, 0.15880591]),
#  'goat': array([-0.04421288,  0.18609753]),
#  'feta': array([-0.02069613,  0.21106891]),
#  'oranges': array([0.4846485 , 0.53643477]),
#  'turmeric': array([-0.43182823, -0.75559855]),
#  'coriander': array([-0.43654615, -0.78427041]),
#  'steaks': array([-0.00552871,  0.24027079]),
#  'steak': array([0.00963681, 0.27466819]),
#  'cardamom': array([ 0.48994124, -0.57726604]),
#  'banana': array([ 0.33766052, -0.38366112]),
#  'bananas': array([ 0.31645268, -0.33760172]),
#  'horseradish': array([ 0.82417709, -0.41568321]),
#  'mayonnaise': array([ 0.78418887, -0.39695969]),
#  'spaghetti': array([-0.25777012,  0.47658622]),
#  'pasta': array([-0.21479213,  0.48682895]),
#  'panko': array([0.35000348, 0.81642348]),
#  'breadcrumbs': array([0.36647984, 0.85359222]),
#  'rib': array([0.14461225, 0.71121383]),
#  'ribs': array([0.15433106, 0.75398737]),
#  'peaches': array([ 0.29122227, -0.28205487]),
#  'apples': array([ 0.28261387, -0.30854228]),
#  'grape': array([ 0.16556437, -0.94574827]),
#  'cherry': array([ 0.17529543, -0.93368512]),
#  'raspberry': array([ 0.33219093, -0.20099412]),
#  'shiitake': array([-0.35342246,  0.64086831]),
#  'mushrooms': array([-0.37666798,  0.6496408 ]),
#  'veal': array([-0.06258995,  0.36591938]),
#  'baguette': array([-0.279984  , -0.44983828]),
#  'bread': array([-0.30094242, -0.49024579]),
#  'tuna': array([0.18375392, 0.07036716]),
#  'berries': array([ 0.27439353, -0.24607056]),
#  'tartar': array([0.94184613, 0.15007521]),
#  'sour': array([0.92445302, 0.14598683]),
#  'cauliflower': array([0.62499207, 0.15365215]),
#  'pears': array([ 0.27019012, -0.28362283]),
#  'romano': array([-0.13500112,  0.08487853]),
#  'grapeseed': array([ 0.04275218, -0.91504014]),
#  'scallion': array([ 0.26746038, -0.85906726]),
#  'scallions': array([ 0.25740379, -0.86845297]),
#  'fillet': array([0.12722617, 0.05395011]),
#  'preserves': array([-0.93428135, -0.39242151]),
#  'jam': array([-0.91480565, -0.38370797]),
#  'avocados': array([ 0.35615239, -0.33584476]),
#  'loin': array([-0.10209047,  0.35521013]),
#  'shoulder': array([-0.11173467,  0.36958063]),
#  'espresso': array([ 0.08651465, -0.20406583]),
#  'cocoa': array([ 0.11840592, -0.19249053]),
#  'coffee': array([ 0.06524809, -0.21785434]),
#  'cracker': array([-0.37820792, -0.55014926]),
#  'crackers': array([-0.42154604, -0.56654751]),
#  'scallops': array([-0.46500605, -0.42422283]),
#  'shrimp': array([-0.49390024, -0.43420705]),
#  'eggplant': array([-0.72339708,  0.23069015]),
#  'tenderloin': array([-0.09875692,  0.34500402]),
#  'hazelnuts': array([-0.09643838,  0.75288731]),
#  'apricots': array([ 0.23814061, -0.31055376]),
#  'apricot': array([ 0.34439966, -0.21099275]),
#  'pecorino': array([-0.13698681,  0.07739098]),
#  'strawberry': array([ 0.31758103, -0.20711561]),
#  'cucumbers': array([0.20099358, 0.3280803 ]),
#  'cucumber': array([0.18875028, 0.32654837]),
#  'tortilla': array([0.7439394 , 0.50258142]),
#  'tortillas': array([0.70704091, 0.47518849]),
#  'watercress': array([0.24877986, 0.29739419]),
#  'herbs': array([0.6859867 , 0.41417372]),
#  'mascarpone': array([-0.47760034, -0.66324335]),
#  'ricotta': array([-0.45106077, -0.6251626 ]),
#  'pancetta': array([-0.27962476,  0.22485036]),
#  'bacon': array([-0.31189218,  0.243237  ]),
#  'prosciutto': array([-0.235268  ,  0.19531457]),
#  'radishes': array([0.19821897, 0.30136696]),
#  'tequila': array([-0.02712885, -0.39286393]),
#  'peach': array([ 0.32417461, -0.23533189]),
#  'chorizo': array([-0.70432067,  0.33119804]),
#  'sausage': array([-0.72218508,  0.33327794]),
#  'jalapeño': array([-0.21201371,  0.01786417]),
#  'marjoram': array([0.69962597, 0.40067521]),
#  'blackberries': array([ 0.281654  , -0.24985273]),
#  'chilies': array([-0.23082103,  0.00455115]),
#  'gin': array([-0.05300656, -0.37693679]),
#  'champagne': array([-0.07935324, -0.39115453]),
#  'vermouth': array([-0.05768469, -0.44082725]),
#  'wine': array([-0.06096563, -0.48798001]),
#  'grapefruit': array([0.48351988, 0.54297566]),
#  'pear': array([ 0.30306104, -0.2640315 ]),
#  'penne': array([-0.24186218,  0.49588171]),
#  'dates': array([ 0.22368364, -0.34465474]),
#  'cookie': array([ 0.16146281, -0.47852305]),
#  'cookies': array([ 0.16044994, -0.4332023 ]),
#  'pistachios': array([-0.09035227,  0.73847878]),
#  'peanuts': array([-0.06392045,  0.73887128]),
#  'jalapenos': array([-0.20512141,  0.00592789]),
#  'macaroni': array([-0.2251292 ,  0.47108948]),
#  'tabasco': array([0.62094516, 0.48148903]),
#  'worcestershire': array([0.64893013, 0.51194489]),
#  'lentils': array([-0.62340194,  0.39506727]),
#  'chickpeas': array([-0.59952414,  0.37481737]),
#  'crab': array([-0.53799486, -0.50740308]),
#  'crabmeat': array([-0.55522257, -0.53767484]),
#  'gruyere': array([-0.13009216,  0.10018788]),
#  'cheddar': array([-0.13655087,  0.11539567]),
#  'walnut': array([-0.35814241, -0.89736366]),
#  'pecan': array([-0.35030672, -0.88212317]),
#  'lobster': array([-0.52246743, -0.46513084]),
#  'tart': array([-0.9644978 , -0.23379445]),
#  'pie': array([-0.92087388, -0.22850157]),
#  'portobello': array([-0.3271504 ,  0.63129663]),
#  'agave': array([-0.55835348, -0.75756216]),
#  'maple': array([-0.54876828, -0.77030778]),
#  'provolone': array([-0.13432519,  0.13543676]),
#  'mozzarella': array([-0.15901339,  0.14022008]),
#  'whiskey': array([ 0.06486224, -0.40037158]),
#  'hamburger': array([-0.35009933, -0.35212478]),
#  'buns': array([-0.3171114, -0.3653059]),
#  'figs': array([ 0.24356441, -0.30439734]),
#  'quinoa': array([-0.65678066,  0.42272404]),
#  'couscous': array([-0.6826396,  0.4432936]),
#  'cannellini': array([-0.68657809, -0.27000123]),
#  'kidney': array([-0.71662593, -0.27341339]),
#  'watermelon': array([ 0.37362355, -0.30739611]),
#  'cod': array([0.12566008, 0.05928798]),
#  'rye': array([-0.23271221, -0.48013651]),
#  'sourdough': array([-0.24297148, -0.44860607]),
#  'mussels': array([-0.60228884, -0.45558533]),
#  'clams': array([-0.61303246, -0.45014074]),
#  'garbanzo': array([-0.7141093 , -0.28394213]),
#  'american': array([-0.12184687,  0.13932608]),
#  'habanero': array([-0.24658024,  0.01469202]),
#  'chipotle': array([-0.29606539,  0.01589113]),
#  'currants': array([ 0.20854339, -0.32331043]),
#  'raisins': array([ 0.1884736, -0.3569594]),
#  'pickles': array([-0.97389364, -0.27945566]),
#  'pickle': array([-0.9892965, -0.2756398]),
#  'cashews': array([-0.07754977,  0.73947901]),
#  'caraway': array([-0.63777244,  0.61268032]),
#  'sunflower': array([-0.64673579,  0.60604268]),
#  'tomatillos': array([-0.24943773, -0.03609727]),
#  'parsnips': array([0.82138151, 0.28005591]),
#  'porcini': array([-0.37861711,  0.68089616]),
#  'marinara': array([-0.3355749 ,  0.48581162]),
#  'linguine': array([-0.2286372 ,  0.49516118]),
#  'poppy': array([-0.61802298,  0.58957368]),
#  'peppermint': array([0.52048278, 0.69790035]),
#  'radicchio': array([0.28069648, 0.31340918]),
#  'gorgonzola': array([-0.01256469,  0.20167826]),
#  'eggplants': array([-0.76205087,  0.24094534]),
#  'plums': array([ 0.27260658, -0.29398334]),
#  'cottage': array([-0.42700821, -0.59128213]),
#  'oysters': array([-0.6498521 , -0.46339992]),
#  'sausages': array([-0.68989617,  0.32488224]),
#  'brisket': array([0.15679045, 0.77727175]),
#  'snapper': array([0.11194844, 0.05236091]),
#  'artichokes': array([-0.09786331, -0.9630059 ]),
#  'artichoke': array([-0.0958528 , -0.97852671]),
#  'brioche': array([-0.26819098, -0.45567864]),
#  'rhubarb': array([ 0.27378631, -0.25569654]),
#  'endive': array([0.27102739, 0.31798157]),
#  'melon': array([ 0.39143944, -0.31616634]),
#  'turnips': array([0.82148421, 0.29298908]),
#  'beets': array([0.86325717, 0.31725642]),
#  'sambal': array([-0.76923722,  0.00616353]),
#  'sriracha': array([-0.80662102,  0.00647023]),
#  'ciabatta': array([-0.25597766, -0.44159952]),
#  'sandwich': array([-0.24292356, -0.48233086]),
#  'salami': array([-0.20516272,  0.17204095]),
#  'pepperoni': array([-0.18805283,  0.16365214]),
#  'barley': array([-0.65600038,  0.41234285]),
#  'papaya': array([ 0.35026088, -0.30984157]),
#  'fettuccine': array([-0.22969902,  0.48881534]),
#  'jasmine': array([-0.29014227, -0.80704939]),
#  'basmati': array([-0.28051126, -0.81252682]),
#  'gingerroot': array([-0.67508465, -0.5630604 ]),
#  'ginger': array([-0.70010483, -0.58139932]),
#  'amaretto': array([ 0.02041129, -0.29204816]),
#  'prunes': array([ 0.22772509, -0.33222255]),
#  'seltzer': array([-0.07075806, -0.3948521 ]),
#  'lemonade': array([-0.05445677, -0.36088824]),
#  'anchovies': array([-0.50823629,  0.6637817 ]),
#  'capers': array([-0.47006503,  0.62246501]),
#  'anchovy': array([-0.5389694 ,  0.69668025]),
#  'skirt': array([-0.05570069,  0.24276204]),
#  'sirloin': array([-0.06340891,  0.26519585]),
#  'lobsters': array([-0.53476977, -0.45267516]),
#  'trout': array([0.12324995, 0.05122925]),
#  'mangoes': array([ 0.33524251, -0.30510938]),
#  'cantaloupe': array([ 0.36458075, -0.31279349]),
#  'butterflied': array([0.2075685, 0.6674338]),
#  'tail': array([0.2304693 , 0.72186548]),
#  'fudge': array([ 0.25242779, -0.14954063]),
#  'caramel': array([ 0.28238246, -0.13100545]),
#  'schnapps': array([ 0.03402362, -0.36395097]),
#  'tenderloins': array([-0.09530908,  0.3527717 ]),
#  'crema': array([ 0.13667561, -0.89466965]),
#  'salsa': array([ 0.14412402, -0.8870126 ]),
#  'kielbasa': array([-0.72255534,  0.34341872]),
#  'squid': array([-0.48002166, -0.42354119]),
#  'beefsteak': array([-0.85038167,  0.19542758]),
#  'plum': array([-0.89301944,  0.20897982]),
#  'radish': array([0.17902918, 0.31743413]),
#  'brie': array([-0.10089768,  0.14822885]),
#  'biscuit': array([ 0.50047523, -0.61243767]),
#  'biscuits': array([ 0.51741523, -0.6303606 ]),
#  'gouda': array([-0.12587319,  0.11310536]),
#  'wafers': array([ 0.82630509, -0.20693904]),
#  'wafer': array([ 0.78436679, -0.19694425]),
#  'edamame': array([ 0.7817806 , -0.10191622]),
#  'peas': array([ 0.74649853, -0.09533923]),
#  'drumsticks': array([-0.44341645,  0.02530561]),
#  'breast': array([-0.4811208 ,  0.01756941]),
#  'wings': array([-0.46829841,  0.00652423]),
#  'chickens': array([-0.42460671,  0.06097205]),
#  'tangerine': array([0.47600543, 0.55225235]),
#  'lager': array([-0.08754222, -0.14685616]),
#  'beer': array([-0.11303554, -0.16830535]),
#  'pistachio': array([-0.28107435,  0.88493401]),
#  'macadamia': array([-0.29887587,  0.9006297 ]),
#  'tenders': array([-0.49570373,  0.00220791]),
#  'rotisserie': array([-0.52989024, -0.00392732]),
#  'honeydew': array([ 0.39264664, -0.32811093]),
#  'berry': array([ 0.31920472, -0.19642691]),
#  'cranberry': array([ 0.34384906, -0.17623788]),
#  'yams': array([0.82259399, 0.261314  ]),
#  'tilapia': array([0.10669579, 0.07852761]),
#  'muffins': array([ 0.36944142, -0.74848515]),
#  'muffin': array([ 0.39295503, -0.78718346]),
#  'venison': array([-0.06422897,  0.32178262]),
#  'cola': array([ 0.0838614 , -0.44121036]),
#  'guacamole': array([ 0.13347495, -0.8523643 ]),
#  'turnip': array([0.82494396, 0.28716013]),
#  'pretzels': array([0.11462826, 0.34085226]),
#  'pretzel': array([0.11118553, 0.29561192]),
#  'bulgur': array([-0.67988265,  0.4306002 ]),
#  'prawns': array([-0.48934853, -0.42639703]),
#  'brownie': array([ 0.1980651 , -0.21231972]),
#  'cake': array([ 0.1762621 , -0.23559748]),
#  'liver': array([-0.60430223, -0.02198167]),
#  'giblets': array([-0.64647198, -0.02562898]),
#  'gruyère': array([-0.12574421,  0.09660672]),
#  'shanks': array([-0.08101963,  0.39139175]),
#  'blueberry': array([ 0.3243883 , -0.20079832]),
#  'prosecco': array([-0.08182498, -0.35729054]),
#  'rotini': array([-0.23607437,  0.50339574]),
#  'pepperoncini': array([-0.07801501,  0.07163508]),
#  'pimento': array([-0.04746308,  0.09271444]),
#  'harissa': array([-0.71712184,  0.63069308]),
#  'tahini': array([-0.75375921,  0.656362  ]),
#  'madeira': array([-0.32081917, -0.30528343]),
#  'marsala': array([-0.27945665, -0.30906081]),
#  'nectarines': array([ 0.30107415, -0.2796776 ]),
#  'nicoise': array([0.45089084, 0.94965297]),
#  'kalamata': array([0.43475521, 0.91617787]),
#  'pimiento': array([-0.041651  ,  0.10357133]),
#  'safflower': array([ 0.04160229, -0.89112949]),
#  'pumpernickel': array([-0.24888247, -0.45597911]),
#  'chipotles': array([-0.27919307,  0.00672716]),
#  'kiwi': array([ 0.35961753, -0.31948102]),
#  'swordfish': array([0.03935278, 0.1512538 ]),
#  'nut': array([-0.29484329,  0.93514013]),
#  'enchilada': array([-0.37023908,  0.5086748 ]),
#  'guava': array([ 0.36405864, -0.20847923]),
#  'tamarind': array([ 0.41272709, -0.20507866]),
#  'tabasco®': array([0.66191798, 0.5171836 ]),
#  'franks': array([0.69519871, 0.54696423]),
#  'drink': array([-0.09687172, -0.36130422]),
#  'shank': array([-0.10497345,  0.38012931]),
#  'crabs': array([-0.52455753, -0.45160663]),
#  'fusilli': array([-0.24120955,  0.50453562]),
#  'crawfish': array([-0.52209544, -0.43855014]),
#  'blackberry': array([ 0.33836991, -0.19703312]),
#  'livers': array([-0.55516082, -0.01313924]),
#  'spareribs': array([-0.11838217,  0.36374307]),
#  'arrowroot': array([-0.06409388,  0.99147844]),
#  'cornstarch': array([-0.07722837,  1.        ]),
#  'tortellini': array([-0.20079248,  0.48823339]),
#  'sole': array([0.12382435, 0.06369235]),
#  'parsnip': array([0.84698468, 0.29148269]),
#  'pitas': array([-0.30530271, -0.39640576]),
#  'pita': array([-0.31696668, -0.41333276]),
#  'breads': array([-0.29030892, -0.40793958]),
#  'burger': array([-0.35198945, -0.32604396]),
#  'cashew': array([-0.28526723,  0.86644638]),
#  'grapefruits': array([0.49889922, 0.52589536]),
#  'mangos': array([ 0.33750704, -0.31059426]),
#  'ravioli': array([-0.16569123,  0.51138866]),
#  'fenugreek': array([-0.41668388, -0.7811172 ]),
#  'roquefort': array([-0.02999144,  0.18447968]),
#  'calamari': array([-0.50173438, -0.42228884]),
#  'focaccia': array([-0.2685945 , -0.41737562]),
#  'kiwis': array([ 0.34379396, -0.32146451]),
#  'gingersnap': array([ 0.76299268, -0.19189043]),
#  'limoncello': array([-0.01537501, -0.33947632]),
#  'mayo': array([ 0.78891873, -0.41232225]),
#  'hummus': array([-0.38087997, -0.19570644]),
#  'pesto': array([-0.3554045 , -0.22998506]),
#  'stilton': array([-0.02054093,  0.20194118]),
#  'tapenade': array([-0.32463148, -0.2813766 ]),
#  'amaretti': array([ 0.7387538 , -0.18624416]),
#  'splenda': array([-0.21730897,  0.81325054]),
#  'sweetener': array([-0.21938723,  0.80244267]),
#  'rutabaga': array([0.83169347, 0.29536414]),
#  'linguini': array([-0.23369093,  0.49190596]),
#  'baguettes': array([-0.28097373, -0.41452456]),
#  'merlot': array([-0.21967407, -0.32364795]),
#  'chardonnay': array([-0.19474877, -0.32950708]),
#  'plantain': array([ 0.54325122, -0.75251061]),
#  'plantains': array([ 0.56797093, -0.78361106]),
#  'ganache': array([ 0.30757946, -0.10791557]),
#  'buttercream': array([ 0.3421827 , -0.08514336]),
#  'sherbet': array([ 0.00203476, -0.40899655]),
#  'sorbet': array([ 0.01357813, -0.46199894]),
#  'kahlua': array([ 0.03661684, -0.23253666]),
#  'gnocchi': array([-0.14993072,  0.54400903]),
#  'frangelico': array([ 0.0180351 , -0.28309152]),
#  'nutella': array([0.05357647, 0.84483033]),
#  'hazelnut': array([0.0432521 , 0.83423162]),
#  'havarti': array([-0.1071536 ,  0.11992158]),
#  'goose': array([-0.41032964,  0.09699765]),
#  'jalapeños': array([-0.17781526,  0.02524443]),
#  'picante': array([-0.36253858,  0.5144729 ]),
#  'valrhona': array([0.09151933, 0.02858981]),
#  'lindt': array([ 0.08457906, -0.03821443]),
#  'shortbread': array([ 0.15735365, -0.36024606]),
#  'naan': array([-0.29906714, -0.41908917]),
#  'hersheys': array([0.09879653, 0.07988957]),
#  'krispies®': array([-0.25936326, -0.75934744]),
#  'cereal': array([-0.25995678, -0.77104092]),
#  'flatbread': array([-0.28981772, -0.39213508]),
#  'fajita': array([ 0.71724045, -0.45861363]),
#  'taco': array([ 0.75240761, -0.48330969]),
#  'cajun': array([ 0.67544651, -0.4290747 ]),
#  'stevia': array([-0.22622269,  0.84764463]),
#  'guinness': array([-0.09271237, -0.15601659]),
#  'rabbit': array([-0.04634209,  0.36224288]),
#  'octopus': array([-0.50539005, -0.44657028]),
#  'soybeans': array([ 0.79444253, -0.11177025]),
#  'kelloggs®': array([-0.25430572, -0.73114407]),
#  'broccolini': array([0.68455416, 0.15732832]),
#  'zucchinis': array([-0.61295694,  0.20299228]),
#  'heinz': array([-0.62654787, -0.60696656]),
#  'ketchup': array([-0.62232119, -0.58848655]),
#  'parma': array([-0.24605463,  0.18650708]),
#  'margarita': array([-0.08791618, -0.38244823]),
#  'udon': array([-0.27751818,  0.55471313]),
#  'vermicelli': array([-0.26390377,  0.55960804]),
#  'ramen': array([-0.29936886,  0.58032656]),
#  'monkfish': array([0.10452292, 0.07469857]),
#  'whitefish': array([0.13699448, 0.05737641]),
#  'splenda®': array([-0.21996439,  0.78404903]),
#  'pappardelle': array([-0.24824947,  0.50179178]),
#  'lettuces': array([0.27429971, 0.30862162]),
#  'consomme': array([-0.23003168, -0.9107042 ]),
#  'bison': array([-0.07668054,  0.28935695]),
#  'applejack': array([ 0.05221204, -0.39317289]),
#  'kabocha': array([0.59873003, 0.72767919]),
#  'butternut': array([0.6038087 , 0.71445256]),
#  'gelato': array([ 0.02058154, -0.50429368]),
#  'camembert': array([-0.07474643,  0.14539628]),
#  'porterhouse': array([-0.03206666,  0.2133335 ]),
#  'muscle': array([0.25017932, 0.76022887]),
#  'clementines': array([0.49646708, 0.54029924]),
#  'caesar': array([-0.49774826,  0.88922024]),
#  'ranch': array([-0.51653969,  0.9210633 ]),
#  'pancakes': array([ 0.90639418, -0.01571306]),
#  'pancake': array([ 0.92008662, -0.00424004]),
#  'crepes': array([ 0.8694762 , -0.01715169]),
#  'szechuan': array([-0.72852707,  0.72115594]),
#  'sichuan': array([-0.71480536,  0.7253201 ]),
#  'biscotti': array([ 0.17531653, -0.47601795]),
#  'cheeses': array([-0.83713293, -0.2713044 ]),
#  'cheese': array([-0.84563023, -0.25898096]),
#  'crostini': array([-0.29461983, -0.34915259]),
#  'chocolates': array([0.17845909, 0.84837443]),
#  'chocolate': array([0.19274749, 0.8521874 ]),
#  'tagliatelle': array([-0.24491772,  0.48401725]),
#  'glutamate': array([ 0.81390709, -0.28854641]),
#  'msg': array([ 0.78649014, -0.27214226]),
#  'fettuccini': array([-0.2385153 ,  0.49152166]),
#  'seashell': array([-0.25428501,  0.51368678]),
#  'monosodium': array([ 0.81669635, -0.27819315]),
#  'persimmons': array([ 0.33336151, -0.31587255]),
#  'nestle®': array([0.10621362, 0.14584847]),
#  'truvia®': array([-0.22797209,  0.81931943]),
#  'oreo': array([ 0.77319151, -0.19835819]),
#  'cheesecake': array([ 0.16370875, -0.26305279]),
#  'rutabagas': array([0.83777511, 0.28055367]),
#  'groundnut': array([ 0.0435476 , -0.85937649]),
#  'hersheys®': array([0.13597405, 0.11660974]),
#  'clementine': array([0.48562217, 0.55272907]),
#  'lasagne': array([0.7436505 , 0.29444262]),
#  'lasagna': array([0.75751024, 0.3065446 ]),
#  'brownies': array([ 0.16755609, -0.2844654 ]),
#  'sucralose': array([-0.23077969,  0.81227785]),
#  'spaghettini': array([-0.24725778,  0.51835489]),
#  'lychee': array([0.54466802, 0.82488298]),
#  'lychees': array([0.52843332, 0.80089897]),
#  'patty': array([-0.38777068, -0.29703984]),
#  'patties': array([-0.42357343, -0.28954914]),
#  'pimenton': array([-0.92001164, -0.05012235]),
#  'pimentón': array([-0.92036122, -0.06555044]),
#  'dumplings': array([-0.13160089,  0.54715198]),
#  'yellowfin': array([ 0.33712032, -0.78898787]),
#  'sashimi': array([ 0.32646817, -0.79862612]),
#  'barilla': array([-0.23467347,  0.51366699]),
#  'canela': array([ 0.48398998, -0.61247474]),
#  'ducks': array([-0.42136389,  0.06707989]),
#  'bechamel': array([-0.375085  ,  0.48988843]),
#  'pastrami': array([-0.21905194,  0.18029493]),
#  'papayas': array([ 0.34189585, -0.33083931]),
#  'pilsner': array([-0.07855426, -0.14080805]),
#  'bagels': array([-0.31273633, -0.44988176]),
#  'kahlúa': array([ 0.0514583 , -0.20135033]),
#  'callebaut': array([0.09714401, 0.03008983]),
#  'waffles': array([ 0.91568899, -0.02547759]),
#  'gyoza': array([ 0.84878719, -0.05033102]),
#  'wonton': array([ 0.87566328, -0.06079966]),
#  'dumpling': array([ 0.80704761, -0.04663462]),
#  'emmentaler': array([-0.11832272,  0.10295457]),
#  'tumeric': array([-0.44976673, -0.75191808]),
#  'piecrust': array([-0.92734015, -0.24517751]),
#  'godiva': array([ 0.04788999, -0.1314709 ]),
#  'kahlua®': array([ 0.03965821, -0.06859068]),
#  'spearmint': array([0.71313304, 0.32133532]),
#  'peperoncini': array([-0.03881251,  0.08439272]),
#  'skewer': array([ 0.21901588, -0.88381523]),
#  'skewers': array([ 0.22687994, -0.87048709]),
#  'portobellos': array([-0.30596521,  0.6378243 ]),
#  'oreo®': array([ 0.80289447, -0.20539656]),
#  'krispies': array([-0.27200708, -0.77515471]),
#  'nectarine': array([ 0.3158085 , -0.27611479]),
#  'sambuca': array([ 0.0353745 , -0.25870013]),
#  'drumstick': array([-0.45823917,  0.00235465]),
#  'heinz®': array([-0.59642863, -0.58178741]),
#  'halloumi': array([-0.09052031,  0.15597697]),
#  'chimichurri': array([-0.86092979,  0.05119856]),
#  'tzatziki': array([-0.89004087,  0.05278545]),
#  'jalepeno': array([-0.21837972,  0.02792215]),
#  'nutella®': array([0.0585453, 0.8902247]),
#  'calamata': array([0.44540983, 0.9384526 ]),
#  'nougat': array([ 0.35172218, -0.09534713]),
#  'elk': array([-0.07690788,  0.31442252]),
#  'orégano': array([0.75856024, 0.43070215]),
#  'saltines': array([-0.46177903, -0.58179498]),
#  'saltine': array([-0.49117613, -0.6008653 ]),
#  'hellmanns®': array([0.89859927, 0.1879079 ]),
#  'hellmanns': array([0.86872053, 0.18251964]),
#  'rockfish': array([0.11681831, 0.05294069]),
#  'panettone': array([-0.27246392, -0.49959871]),
#  'shellfish': array([-0.56757098, -0.43946218]),
#  'sugars': array([ 0.9068684 , -0.47986302]),
#  'sugar': array([ 0.87054616, -0.46045867]),
#  'colmans': array([-0.87015027,  0.1191348 ]),
#  'colemans': array([-0.83959031,  0.11553175]),
#  'cornflake': array([-0.33912277, -0.5278424 ]),
#  'herring': array([0.18616092, 0.05429663]),
#  'scones': array([ 0.53041977, -0.62190574]),
#  'comte': array([-0.10660387,  0.09911925]),
#  'emmental': array([-0.12092197,  0.09557122]),
#  'shiraz': array([-0.19663934, -0.33824715]),
#  'serranos': array([-0.19679017,  0.0107637 ]),
#  'crayfish': array([-0.52844113, -0.42889684]),
#  'fettucine': array([-0.21935053,  0.50071949]),
#  'gooseberries': array([ 0.30750537, -0.23597057]),
#  'hendricks': array([-0.03546811, -0.37903091]),
#  'soufflé': array([0.08116994, 0.7598933 ]),
#  'souffle': array([0.07575491, 0.7254988 ]),
#  'chowder': array([0.90969902, 0.05575261]),
#  'soup': array([0.87968463, 0.05180883]),
#  'butterfinger®': array([0.11133593, 0.2252454 ]),
#  'cappuccino': array([ 0.65266407, -0.58574784]),
#  'mocha': array([ 0.63807768, -0.57224488]),
#  'cantaloupes': array([ 0.35414535, -0.30195907]),
#  'rosé': array([-0.15581697, -0.34117109]),
#  'chamomile': array([ 0.05887659, -0.9919619 ]),
#  'hibiscus': array([ 0.07373124, -0.98195529]),
#  'chai': array([ 0.04080965, -0.9927001 ]),
#  'kefalotyri': array([-0.10543947,  0.09138387]),
#  'bruschetta': array([-0.32937205, -0.35959536]),
#  'perciatelli': array([-0.25694847,  0.50510126]),
#  'robiola': array([-0.08535507,  0.16424337]),
#  'donuts': array([ 0.32522929, -0.85742033]),
#  'doughnuts': array([ 0.34445369, -0.88550031]),
#  'kiwifruit': array([ 0.33505005, -0.3332251 ]),
#  'avocadoes': array([ 0.35566759, -0.3268404 ]),
#  'emmenthal': array([-0.10987057,  0.10870994]),
#  'shrimps': array([-0.47909638, -0.41234401]),
#  'sucrolose': array([-0.23340571,  0.80515742]),
#  'comté': array([-0.11503873,  0.09382065]),
#  'doughnut': array([ 0.33466074, -0.89055872]),
#  'sprout': array([0.07140309, 0.97578818]),
#  'sprouts': array([0.05656716, 0.97954535]),
#  'proscuitto': array([-0.25386611,  0.19621028]),
#  'bresaola': array([-0.29463693,  0.21264403]),
#  'bolognese': array([-0.37616459,  0.49885684]),
#  'beers': array([-0.05160247, -0.12453907]),
#  'ipa': array([-0.05710343, -0.12949243]),
#  'potsticker': array([ 0.84809607, -0.05909048]),
#  'yoghurt': array([-0.29305458,  0.92257488]),
#  'yogurt': array([-0.27701956,  0.90754086]),
#  'peppadews': array([-0.02804408,  0.09658365]),
#  'claret': array([-0.08096023, -0.37461549]),
#  'wontons': array([-0.11501513,  0.57952809]),
#  'hellmans®': array([0.80506575, 0.17293255]),
#  'edam': array([-0.11619592,  0.08984081]),
#  'boysenberry': array([ 0.33117387, -0.18256271]),
#  'ceylon': array([ 0.46817875, -0.63115078]),
#  'mustards': array([-0.88496548,  0.17407764]),
#  'mustard': array([-0.92942965,  0.18237737]),
#  'guinea': array([-0.4681007 ,  0.03490179]),
#  'pernigotti': array([ 0.04937788, -0.01699176]),
#  'langoustines': array([-0.49145916, -0.3980526 ]),
#  'butterfinger': array([0.18845017, 0.12369224]),
#  'toffee': array([0.23195332, 0.13679802]),
#  'condiments': array([0.3349584 , 0.76742858]),
#  'condiment': array([0.34918776, 0.76260757]),
#  'chipolte': array([-0.33752844,  0.01672759]),
#  'romanesco': array([0.5813756 , 0.14576508]),
#  'haloumi': array([-0.11109158,  0.16010354]),
#  'budweiser': array([-0.07441741, -0.14920388]),
#  'cannelini': array([-0.7315644 , -0.28551584]),
#  'passionfruit': array([ 0.35524645, -0.19151634]),
#  'lipton': array([-0.89926374, -0.11930296]),
#  'lipton®': array([-0.88671434, -0.12708898]),
#  'kelloggs': array([-0.26967502, -0.76036245]),
#  'cuttlefish': array([-0.46756741, -0.40121192]),
#  'snickers': array([0.12010419, 0.08905991]),
#  'ribeye': array([-0.07515159,  0.2506417 ]),
#  'wagyu': array([-0.11089833,  0.27007002]),
#  'chenin': array([-0.18582529, -0.34991434]),
#  'prawn': array([0.24832927, 0.72017437]),
#  'bisque': array([0.89798516, 0.06823154]),
#  'valhrona': array([0.07714946, 0.02946398]),
#  'snickers®': array([0.10687447, 0.10986793]),
#  'keebler': array([0.13707738, 0.14578873]),
#  'pheasants': array([-0.45231277,  0.07376163]),
#  'hellmans': array([0.91349471, 0.19044723]),
#  'foccacia': array([-0.29176122, -0.45885295]),
#  'jellybeans': array([0.07988351, 0.04888192]),
#  'pinenuts': array([-0.09713458,  0.800991  ]),
#  'jagermeister': array([ 0.0080298 , -0.08172405]),
#  'americano': array([-0.17100276, -0.37274477]),
#  'cabbages': array([-0.81140679, -0.1958486 ]),
#  'cabbage': array([-0.83270723, -0.19865069]),
#  'seabass': array([0.12144274, 0.06901487]),
#  'peppermints': array([0.22543372, 0.1493095 ]),
#  'smirnoff®': array([-0.00152561, -0.10933159]),
#  'emmenthaler': array([-0.11071297,  0.08067955]),
#  'starburst®': array([0.09268329, 0.09247321]),
#  'antibiotic': array([ 0.42813361, -0.72648895]),
#  'coconutmilk': array([ 0.44337645, -0.72671443]),
#  'puttanesca': array([-0.85525793,  0.32772329]),
#  'bearnaise': array([-0.84602964,  0.34010953]),
#  'gummi': array([0.07762817, 0.04313876]),
#  'godiva®': array([ 0.11957447, -0.04630398]),
#  'starbucks': array([ 0.04646076, -0.02200364]),
#  'haagen': array([ 0.06021019, -0.04715642]),
#  'blackcurrant': array([ 0.03063564, -0.326727  ]),
#  'gruyére': array([-0.10086502,  0.08662962]),
#  'tomalley': array([0.23902372, 0.75966489]),
#  'brussel': array([-0.52457207,  0.86033821]),
#  'alfalfa': array([-0.50265259,  0.8307941 ]),
#  'sardine': array([0.14138407, 0.07792675]),
#  'kebabs': array([ 0.22013807, -0.83465379]),
#  'hotdogs': array([-0.77430642, -0.30194137]),
#  'blackfish': array([ 0.68718958, -0.417364  ]),
#  'parmigianino': array([-0.12394168,  0.08079622]),
#  'marscarpone': array([ 0.02804482, -0.05746957])}

# %%
nx.set_node_attributes(G, name = "position", values = positions)

# %%
searches = ["potato", "gouda", "crab"]

# %%
edge_x = []
edge_y = []
weights = []
ave_x, ave_y = [], []
for edge in G.edges():
    x0, y0 = G.nodes[edge[0]]['position']
    x1, y1 = G.nodes[edge[1]]['position']
    edge_x.append(x0)
    edge_x.append(x1)
    edge_x.append(None)
    edge_y.append(y0)
    edge_y.append(y1)
    edge_y.append(None)
    ave_x.append(np.mean([x0, x1]))
    ave_y.append(np.mean([y0, y1]))
    weights.append(f'{edge[0]}, {edge[1]}: {weight_values[(edge[0], edge[1])]}')

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    opacity=0.7,
    line=dict(width=2, color='White'),
    hoverinfo='text',
    mode='lines')

edge_trace.text = weights


node_x = []
node_y = []
sizes = []
for node in G.nodes():
    x, y = G.nodes[node]['position']
    node_x.append(x)
    node_y.append(y)
    if node in searches:
        sizes.append(50)
    else:
        sizes.append(15)

node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        line=dict(color='White'),
        # colorscale options
        #'Greys' | 'YlGnBu' | 'Greens' | 'YlOrRd' | 'Bluered' | 'RdBu' |
        #'Reds' | 'Blues' | 'Picnic' | 'Rainbow' | 'Portland' | 'Jet' |
        #'Hot' | 'Blackbody' | 'Earth' | 'Electric' | 'Viridis' |
        colorscale='Picnic',
        reversescale=False,
        color=[],
        opacity=0.9,
        size=sizes,
        colorbar=dict(
            thickness=15,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
        line_width=2
    )
)

invisible_similarity_trace = go.Scatter(
    x=ave_x, y=ave_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        color=[],
        opacity=0,
    )
)

invisible_similarity_trace.text=weights

# %%
node_adjacencies = []
node_text = []
for node, adjacencies in enumerate(G.adjacency()):
    node_adjacencies.append(len(adjacencies[1]))
    node_text.append(adjacencies[0])

node_trace.marker.color = node_adjacencies
node_trace.text = node_text

# %%
fig = go.Figure(
    data=[edge_trace, node_trace, invisible_similarity_trace],
    layout=go.Layout(
        title='Network Graph of Word Embeddings',
        template='plotly_dark',
        titlefont_size=20,
        showlegend=False,
        hovermode='closest',
        margin=dict(b=20,l=5,r=5,t=40),
        annotations=[
            dict(
                text="Adapted from: <a href='https://plotly.com/ipython-notebooks/network-graphs/'> https://plotly.com/ipython-notebooks/network-graphs/</a>",
                showarrow=False,
                xref="paper", yref="paper",
                x=0.005, y=-0.002 ) 
        ],
        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)
    )
)

plot(fig)
# Out:
# 'temp-plot.html'
