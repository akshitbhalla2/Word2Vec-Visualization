# %% [markdown]
# # Interactive Recommendation System with Word Embeddings using Word2Vec, Plotly, and NetworkX
#
# ## Project Breakdown
# - Task 1: Introduction
# - Task 2: Exploratory Data Analysis and Preprocessing (you are here)
# - Task 3: Word2Vec with Gensim
# - Task 4: Exploring Results
# - Task 5: Building and Visualizing Interactive Network Graph
#
# ## Task 2: Exploratory Data Analysis and Preprocessing
#
# [This is the dataset](https://eightportions.com/datasets/Recipes/#fn:1) we will be using. It is collated by Ryan Lee, sourced from [Food Network](https://www.foodnetwork.com/), [Epicurious](https://www.epicurious.com/), and [Allrecipes](https://www.allrecipes.com/).

# %%
from gensim.parsing.preprocessing import remove_stopwords
from tqdm import tqdm
import pandas as pd
import pickle
import string
import json

# %%
recipe_sources = ['ar', 'epi', 'fn']

# %%
df = pd.DataFrame()
sources, titles, ingredients, instructions = [], [], [], []
for recipe_source in recipe_sources:
    data = json.load(open(f'Data/Dataset/recipes_raw_nosource_{recipe_source}.json', 'r'))
    for _, recipe in data.items():
        if ('title' in recipe) and ('ingredients' in recipe) and ('instructions' in recipe):
            # append to a list of the source
            sources.append(recipe_source)
            # append to a list of the titles
            titles.append(recipe["title"])
            # append to a list of ingredients, removing the word ADVERTISEMENT
            ingredients.append([str(ing).replace("ADVERTISEMENT", "") for ing in recipe["ingredients"]])
            # append to a list of instructions, removing the word ADVERTISEMENT and replace \n with space characters
            instructions.append(str(recipe["instructions"]).replace("ADVERTISEMENT", "").replace("\n", " "))
            
df['source'] = sources
df['title'] = titles
df['ingredients'] = ingredients
df['instructions'] = instructions

# %%
df
# Out:
#        source                                   title  \
# 0          ar       Slow Cooker Chicken and Dumplings
# 1          ar           Awesome Slow Cooker Pot Roast
# 2          ar                    Brown Sugar Meatloaf
# 3          ar             Best Chocolate Chip Cookies
# 4          ar       Homemade Mac and Cheese Casserole
# ...       ...                                     ...
# 124642     fn                       Summer Corn Salad
# 124643     fn               Zucchini Stuffed Tomatoes
# 124644     fn                 Pepper Pasta Quick Cook
# 124645     fn  Chocolate Cake with Armagnac Ice Cream
# 124646     fn                           Crabby Bisque
#
#                                               ingredients  \
# 0       [4 skinless, boneless chicken breast halves , ...
# 1       [2 (10.75 ounce) cans condensed cream of mushr...
# 2       [1/2 cup packed brown sugar , 1/2 cup ketchup ...
# 3       [1 cup butter, softened , 1 cup white sugar , ...
# 4       [8 ounces whole wheat rotini pasta , 3 cups fr...
# ...                                                   ...
# 124642  [4 ears fresh corn, 2 heads Belgian endive, 2 ...
# 124643  [4 large plum tomatoes, Salt and sugar, 1 1/2 ...
# 124644  [3 tablespoons olive oil, 2 tablespoons unsalt...
# 124645  [8 ounces butter, 8 ounces bittersweet chocola...
# 124646  [3 (10.5-ounce) cans restaurant-style condense...
#
#                                              instructions
# 0       Place the chicken, butter, soup, and onion in ...
# 1       In a slow cooker, mix cream of mushroom soup, ...
# 2       Preheat oven to 350 degrees F (175 degrees C)....
# 3       Preheat oven to 350 degrees F (175 degrees C)....
# 4       Preheat oven to 350 degrees F. Line a 2-quart ...
# ...                                                   ...
# 124642  Watch how to make this recipe. Preheat a grill...
# 124643  Preheat the broiler. Cut the tomatoes in 1/2 c...
# 124644  Heat the oil and butter in a large skillet ove...
# 124645  Preheat oven to 350 degrees. On the top half o...
# 124646  Watch how to make this recipe. In a medium sau...
#
# [124647 rows x 4 columns]

# %%
def preprocess(items):
    res = []
    for i, item in enumerate(items):
        temp = item.lower().replace("-", " ")
        
        translation_table = str.maketrans("", "", string.punctuation + string.digits)
        
        temp = temp.translate(translation_table)
        temp = remove_stopwords(temp)
        
        to_remove = [
            'tablespoon', 'tablespoons', 'teaspoon', 'teaspoons', 'tsp', 'tsps', 'tbsp',
            'tbsps', 'pound', 'pounds', 'grams', 'mg', 'ounce', 'ounces', 'kg', 'crushed',
            'chopped', 'finely', 'softened', 'cups', 'cup'
        ]
        
        for stop_word in to_remove:
            temp = temp.replace(stop_word, "")
        
        res.append(temp.split())
    
    return res

# %%
instructions = df["instructions"].values.tolist()
ingredients = [", ".join(x) for x in df["ingredients"].values.tolist()]

# %%
train_data = preprocess(instructions+ingredients)

# %%
train_data
# Out:
# [['place',
#   'chicken',
#   'butter',
#   'soup',
#   'onion',
#   'slow',
#   'cooker',
#   'water',
#   'cover',
#   'cover',
#   'cook',
#   'hours',
#   'high',
#   'minutes',
#   'serving',
#   'place',
#   'torn',
#   'biscuit',
#   'dough',
#   'slow',
#   'cooker',
#   'cook',
#   'dough',
#   'longer',
#   'raw',
#   'center'],
#  ['slow',
#   'cooker',
#   'mix',
#   'cream',
#   'mushroom',
#   'soup',
#   'dry',
#   'onion',
#   'soup',
#   'mix',
#   'water',
#   'place',
#   'pot',
#   'roast',
#   'slow',
#   'cooker',
#   'coat',
#   'soup',
#   'mixture',
#   'cook',
#   'high',
#   'setting',
#   'hours',
#   'low',
#   'setting',
#   'hours'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'lightly',
#   'grease',
#   'x',
#   'inch',
#   'loaf',
#   'pan',
#   'press',
#   'brown',
#   'sugar',
#   'prepared',
#   'loaf',
#   'pan',
#   'spread',
#   'ketchup',
#   'sugar',
#   'mixing',
#   'bowl',
#   'mix',
#   'thoroughly',
#   'remaining',
#   'ingredients',
#   'shape',
#   'loaf',
#   'place',
#   'ketchup',
#   'bake',
#   'preheated',
#   'oven',
#   'hour',
#   'juices',
#   'clear'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'cream',
#   'butter',
#   'white',
#   'sugar',
#   'brown',
#   'sugar',
#   'smooth',
#   'beat',
#   'eggs',
#   'time',
#   'stir',
#   'vanilla',
#   'dissolve',
#   'baking',
#   'soda',
#   'hot',
#   'water',
#   'add',
#   'batter',
#   'salt',
#   'stir',
#   'flour',
#   'chocolate',
#   'chips',
#   'nuts',
#   'drop',
#   'large',
#   'spoonfuls',
#   'ungreased',
#   'pans',
#   'bake',
#   'minutes',
#   'preheated',
#   'oven',
#   'edges',
#   'nicely',
#   'browned'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'line',
#   'quart',
#   'casserole',
#   'dish',
#   'reynolds',
#   'wrapr',
#   'pan',
#   'lining',
#   'paper',
#   'parchment',
#   'need',
#   'grease',
#   'dish',
#   'cook',
#   'pasta',
#   'large',
#   'saucepan',
#   'according',
#   'package',
#   'directions',
#   'adding',
#   'broccoli',
#   'minutes',
#   'cooking',
#   'drain',
#   'return',
#   'saucepan',
#   'set',
#   'aside',
#   'cook',
#   'onion',
#   'garlic',
#   's',
#   'hot',
#   'butter',
#   'large',
#   'skillet',
#   'minutes',
#   'tender',
#   'stir',
#   'flour',
#   'salt',
#   'black',
#   'pepper',
#   'add',
#   'milk',
#   'cook',
#   'stir',
#   'medium',
#   'heat',
#   'slightly',
#   'thickened',
#   'bubbly',
#   'add',
#   'cheddar',
#   'cheese',
#   'cream',
#   'cheese',
#   'stirring',
#   'melted',
#   'pour',
#   'cheese',
#   'sauce',
#   'pasta',
#   'broccoli',
#   'stir',
#   'combined',
#   'melt',
#   'remaining',
#   's',
#   'butter',
#   'mix',
#   'bread',
#   'crumbs',
#   'small',
#   'bowl',
#   'transfer',
#   'pasta',
#   'mixture',
#   'prepared',
#   'casserole',
#   'dish',
#   'buttery',
#   'bread',
#   'crumbs',
#   'bake',
#   'uncovered',
#   'minutes',
#   'bubbly',
#   'internal',
#   'temperature',
#   'degrees',
#   'f',
#   'let',
#   'stand',
#   'minutes',
#   'serving'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'lightly',
#   'grease',
#   'x',
#   'inch',
#   'loaf',
#   'pan',
#   'large',
#   'bowl',
#   'combine',
#   'flour',
#   'baking',
#   'soda',
#   'salt',
#   'separate',
#   'bowl',
#   'cream',
#   'butter',
#   'brown',
#   'sugar',
#   'stir',
#   'eggs',
#   'mashed',
#   'bananas',
#   'blended',
#   'stir',
#   'banana',
#   'mixture',
#   'flour',
#   'mixture',
#   'stir',
#   'moisten',
#   'pour',
#   'batter',
#   'prepared',
#   'loaf',
#   'pan',
#   'bake',
#   'preheated',
#   'oven',
#   'minutes',
#   'toothpick',
#   'inserted',
#   'center',
#   'loaf',
#   'comes',
#   'clean',
#   'let',
#   'bread',
#   'cool',
#   'pan',
#   'minutes',
#   'turn',
#   'wire',
#   'rack'],
#  ['bring',
#   'large',
#   'saucepan',
#   'salted',
#   'water',
#   'boil',
#   'add',
#   'russet',
#   'potatoes',
#   'boiling',
#   'water',
#   'cook',
#   'tender',
#   'minutes',
#   'drain',
#   'mash',
#   's',
#   'butter',
#   'thoroughly',
#   'combined',
#   'season',
#   'nutmeg',
#   'salt',
#   'black',
#   'pepper',
#   'cayenne',
#   'pepper',
#   'taste',
#   'mash',
#   'milk',
#   'potato',
#   'mixture',
#   'smooth',
#   'drizzle',
#   'olive',
#   'oil',
#   'large',
#   'dutch',
#   'oven',
#   'medium',
#   'high',
#   'heat',
#   'add',
#   'spinach',
#   'season',
#   'big',
#   'pinch',
#   'salt',
#   'cook',
#   'stirring',
#   'occasionally',
#   'spinach',
#   'wilted',
#   'minute',
#   'transfer',
#   'bowl',
#   'lined',
#   'paper',
#   'towels',
#   'wick',
#   'away',
#   'excess',
#   'moisture',
#   'heat',
#   's',
#   'butter',
#   'flour',
#   'saucepan',
#   'medium',
#   'heat',
#   'whisk',
#   'mixture',
#   'smooth',
#   'paste',
#   'cook',
#   'stirring',
#   'constantly',
#   'mixture',
#   'nutty',
#   'smell',
#   'slightly',
#   'browned',
#   'minutes',
#   'add',
#   'garlic',
#   'whisk',
#   'fragrant',
#   'seconds',
#   'whisk',
#   'cold',
#   'milk',
#   'flour',
#   'mixture',
#   'cook',
#   'thickened',
#   'whisk',
#   'remaining',
#   'milk',
#   'lemon',
#   'zest',
#   'bring',
#   'white',
#   'sauce',
#   'gentle',
#   'simmer',
#   'whisking',
#   'constantly',
#   'season',
#   'salt',
#   'turn',
#   'heat',
#   'low',
#   'sauce',
#   'warm',
#   'preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'grease',
#   'x',
#   'inch',
#   'casserole',
#   'dish',
#   'butter',
#   'season',
#   'buttered',
#   'pan',
#   'salt',
#   'black',
#   'pepper',
#   'cayenne',
#   'pepper',
#   'lay',
#   'boneless',
#   'cod',
#   'fillets',
#   'pan',
#   'single',
#   'layer',
#   'season',
#   'tops',
#   'fillets',
#   'salt',
#   'black',
#   'pepper',
#   'cayenne',
#   'pepper',
#   'spread',
#   'spinach',
#   'evenly',
#   'fish',
#   'drizzle',
#   'lemon',
#   'juice',
#   'spoon',
#   'white',
#   'sauce',
#   'spinach',
#   'casserole',
#   'dish',
#   'taps',
#   'shakes',
#   'eliminate',
#   'bubbles',
#   'drop',
#   'mashed',
#   'potatoes',
#   'heaping',
#   'spoonfuls',
#   'casserole',
#   'spread',
#   'smoothly',
#   'cover',
#   'place',
#   'dish',
#   'rimmed',
#   'baking',
#   'sheet',
#   'catch',
#   'spills',
#   'bake',
#   'preheated',
#   'oven',
#   'bubbling',
#   'minutes',
#   'turn',
#   'ovens',
#   'broiler',
#   'broil',
#   'potato',
#   'crust',
#   'golden',
#   'brown',
#   'minutes',
#   'fish',
#   'flake',
#   'easily',
#   'let',
#   'stand',
#   'minutes',
#   'serving',
#   'garnish',
#   'sprinkle',
#   'chives'],
#  ['grease',
#   'flour',
#   'x',
#   'inch',
#   'pans',
#   'preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'sift',
#   'flour',
#   'salt',
#   'baking',
#   'powder',
#   'soda',
#   'cinnamon',
#   'bowl',
#   'beat',
#   'eggs',
#   'oil',
#   'vanilla',
#   'sugar',
#   'large',
#   'bowl',
#   'add',
#   'sifted',
#   'ingredients',
#   'creamed',
#   'mixture',
#   'beat',
#   'stir',
#   'zucchini',
#   'nuts',
#   'combined',
#   'pour',
#   'batter',
#   'prepared',
#   'pans',
#   'bake',
#   'minutes',
#   'tester',
#   'inserted',
#   'center',
#   'comes',
#   'clean',
#   'cool',
#   'pan',
#   'rack',
#   'minutes',
#   'remove',
#   'bread',
#   'pan',
#   'completely',
#   'cool'],
#  ['large',
#   'bowl',
#   'cream',
#   'butter',
#   'sugar',
#   'smooth',
#   'beat',
#   'eggs',
#   'vanilla',
#   'stir',
#   'flour',
#   'baking',
#   'powder',
#   'salt',
#   'cover',
#   'chill',
#   'dough',
#   'hour',
#   'overnight',
#   'preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'roll',
#   'dough',
#   'floured',
#   'surface',
#   'inch',
#   'cut',
#   'shapes',
#   'cookie',
#   'cutter',
#   'place',
#   'cookies',
#   'inch',
#   'apart',
#   'ungreased',
#   'cookie',
#   'sheets',
#   'bake',
#   'minutes',
#   'preheated',
#   'oven',
#   'cool',
#   'completely'],
#  ['whisk',
#   'ketchup',
#   'chicken',
#   'broth',
#   'egg',
#   'soy',
#   'sauce',
#   'chile',
#   'garlic',
#   'sauce',
#   'oyster',
#   'sauce',
#   'tamarind',
#   'paste',
#   'fish',
#   'sauce',
#   'palm',
#   'sugar',
#   'bowl',
#   'stir',
#   'shallots',
#   'garlic',
#   'oil',
#   'ginger',
#   'serrano',
#   'pepper',
#   'pot',
#   'medium',
#   'high',
#   'heat',
#   'saute',
#   'sizzling',
#   'minutes',
#   'add',
#   'crab',
#   'pot',
#   'cover',
#   'pot',
#   'lid',
#   'shake',
#   'crab',
#   'completely',
#   'coated',
#   'shallot',
#   'mixture',
#   'remove',
#   'lid',
#   'cook',
#   'stir',
#   'heated',
#   'minutes',
#   'pour',
#   'ketchup',
#   'mixture',
#   'pot',
#   'reduce',
#   'heat',
#   'medium',
#   'cook',
#   'stir',
#   'sauce',
#   'thickens',
#   'crab',
#   'hot',
#   'minutes',
#   'remove',
#   'heat',
#   'stir',
#   'cilantro',
#   'green',
#   'onions'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'grease',
#   'flour',
#   'x',
#   'inch',
#   'loaf',
#   'pans',
#   'large',
#   'bowl',
#   'mix',
#   'pumpkin',
#   'puree',
#   'eggs',
#   'oil',
#   'water',
#   'sugar',
#   'blended',
#   'separate',
#   'bowl',
#   'whisk',
#   'flour',
#   'baking',
#   'soda',
#   'salt',
#   'cinnamon',
#   'nutmeg',
#   'cloves',
#   'ginger',
#   'stir',
#   'dry',
#   'ingredients',
#   'pumpkin',
#   'mixture',
#   'blended',
#   'pour',
#   'prepared',
#   'pans',
#   'bake',
#   'minutes',
#   'preheated',
#   'oven',
#   'loaves',
#   'toothpick',
#   'inserted',
#   'center',
#   'comes',
#   'clean'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'grease',
#   'cookie',
#   'sheets',
#   'line',
#   'parchment',
#   'paper',
#   'sift',
#   'flour',
#   'baking',
#   'soda',
#   'salt',
#   'set',
#   'aside',
#   'medium',
#   'bowl',
#   'cream',
#   'melted',
#   'butter',
#   'brown',
#   'sugar',
#   'white',
#   'sugar',
#   'blended',
#   'beat',
#   'vanilla',
#   'egg',
#   'egg',
#   'yolk',
#   'light',
#   'creamy',
#   'mix',
#   'sifted',
#   'ingredients',
#   'blended',
#   'stir',
#   'chocolate',
#   'chips',
#   'hand',
#   'wooden',
#   'spoon',
#   'drop',
#   'cookie',
#   'dough',
#   'time',
#   'prepared',
#   'cookie',
#   'sheets',
#   'cookies',
#   'inches',
#   'apart',
#   'bake',
#   'minutes',
#   'preheated',
#   'oven',
#   'edges',
#   'lightly',
#   'toasted',
#   'cool',
#   'baking',
#   'sheets',
#   'minutes',
#   'transferring',
#   'wire',
#   'racks',
#   'cool',
#   'completely'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'place',
#   'steamer',
#   'insert',
#   'saucepan',
#   'water',
#   'steamer',
#   'bring',
#   'water',
#   'boil',
#   'add',
#   'cauliflower',
#   'cover',
#   'steam',
#   'tender',
#   'minutes',
#   'transfer',
#   'cauliflower',
#   'large',
#   'bowl',
#   'add',
#   'mashed',
#   'potato',
#   'flakes',
#   'milk',
#   'margarine',
#   'mash',
#   'potato',
#   'masher',
#   'fork',
#   'cauliflower',
#   'mixture',
#   'fluffy',
#   'season',
#   'salt',
#   'black',
#   'pepper',
#   'pour',
#   'mixture',
#   'baking',
#   'dish',
#   'sprinkle',
#   'cheddar',
#   'cheese',
#   'bake',
#   'preheated',
#   'oven',
#   'cheese',
#   'melted',
#   'minutes'],
#  ['place',
#   'bacon',
#   'large',
#   'deep',
#   'skillet',
#   'cook',
#   'medium',
#   'high',
#   'heat',
#   'evenly',
#   'brown',
#   'drain',
#   'crumble',
#   'set',
#   'aside',
#   'lamb',
#   'salt',
#   'pepper',
#   'flour',
#   'large',
#   'mixing',
#   'bowl',
#   'toss',
#   'coat',
#   'meat',
#   'evenly',
#   'brown',
#   'meat',
#   'frying',
#   'pan',
#   'bacon',
#   'fat',
#   'place',
#   'meat',
#   'stock',
#   'pot',
#   'leave',
#   'fat',
#   'frying',
#   'pan',
#   'add',
#   'garlic',
#   'yellow',
#   'onion',
#   'saute',
#   'till',
#   'onion',
#   'begins',
#   'golden',
#   'deglaze',
#   'frying',
#   'pan',
#   'water',
#   'add',
#   'garlic',
#   'onion',
#   'mixture',
#   'stock',
#   'pot',
#   'bacon',
#   'pieces',
#   'beef',
#   'stock',
#   'sugar',
#   'cover',
#   'simmer',
#   'hours',
#   'add',
#   'carrots',
#   'onions',
#   'potatoes',
#   'thyme',
#   'bay',
#   'leaves',
#   'wine',
#   'pot',
#   'reduce',
#   'heat',
#   'simmer',
#   'covered',
#   'minutes',
#   'vegetables',
#   'tender'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'grease',
#   'muffin',
#   'line',
#   'muffin',
#   'liners',
#   'combine',
#   'flour',
#   'sugar',
#   'salt',
#   'baking',
#   'powder',
#   'place',
#   'vegetable',
#   'oil',
#   'measuring',
#   'add',
#   'egg',
#   'milk',
#   'mix',
#   'flour',
#   'mixture',
#   'fold',
#   'blueberries',
#   'muffin',
#   'right',
#   'sprinkle',
#   'crumb',
#   'topping',
#   'mixture',
#   'crumb',
#   'topping',
#   'mix',
#   'sugar',
#   'flour',
#   'butter',
#   's',
#   'cinnamon',
#   'mix',
#   'fork',
#   'sprinkle',
#   'muffins',
#   'baking',
#   'bake',
#   'minutes',
#   'preheated',
#   'oven'],
#  ['preheat',
#   'ovens',
#   'broiler',
#   'grease',
#   'broiling',
#   'pan',
#   'line',
#   'pan',
#   'aluminum',
#   'foil',
#   'small',
#   'bowl',
#   'mix',
#   'parmesan',
#   'cheese',
#   'butter',
#   'mayonnaise',
#   'lemon',
#   'juice',
#   'season',
#   'dried',
#   'basil',
#   'pepper',
#   'onion',
#   'powder',
#   'celery',
#   'salt',
#   'mix',
#   'set',
#   'aside',
#   'arrange',
#   'fillets',
#   'single',
#   'layer',
#   'prepared',
#   'pan',
#   'broil',
#   'inches',
#   'heat',
#   'minutes',
#   'flip',
#   'fillets',
#   'broil',
#   'couple',
#   'minutes',
#   'remove',
#   'fillets',
#   'oven',
#   'cover',
#   'parmesan',
#   'cheese',
#   'mixture',
#   'broil',
#   'minutes',
#   'topping',
#   'browned',
#   'fish',
#   'flakes',
#   'easily',
#   'fork',
#   'careful',
#   'cook',
#   'fish'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'sift',
#   'flour',
#   'baking',
#   'soda',
#   'set',
#   'aside',
#   'large',
#   'bowl',
#   'cream',
#   'butter',
#   'brown',
#   'sugar',
#   'white',
#   'sugar',
#   'beat',
#   'instant',
#   'pudding',
#   'mix',
#   'blended',
#   'stir',
#   'eggs',
#   'vanilla',
#   'blend',
#   'flour',
#   'mixture',
#   'finally',
#   'stir',
#   'chocolate',
#   'chips',
#   'nuts',
#   'drop',
#   'cookies',
#   'rounded',
#   'spoonfuls',
#   'ungreased',
#   'cookie',
#   'sheets',
#   'bake',
#   'minutes',
#   'preheated',
#   'oven',
#   'edges',
#   'golden',
#   'brown'],
#  ['dutch',
#   'oven',
#   'cook',
#   'sausage',
#   'ground',
#   'beef',
#   'onion',
#   'garlic',
#   'medium',
#   'heat',
#   'browned',
#   'stir',
#   'tomatoes',
#   'tomato',
#   'paste',
#   'tomato',
#   'sauce',
#   'water',
#   'season',
#   'sugar',
#   'basil',
#   'fennel',
#   'seeds',
#   'italian',
#   'seasoning',
#   'salt',
#   'pepper',
#   's',
#   'parsley',
#   'simmer',
#   'covered',
#   'hours',
#   'stirring',
#   'occasionally',
#   'bring',
#   'large',
#   'pot',
#   'lightly',
#   'salted',
#   'water',
#   'boil',
#   'cook',
#   'lasagna',
#   'noodles',
#   'boiling',
#   'water',
#   'minutes',
#   'drain',
#   'noodles',
#   'rinse',
#   'cold',
#   'water',
#   'mixing',
#   'bowl',
#   'combine',
#   'ricotta',
#   'cheese',
#   'egg',
#   'remaining',
#   'parsley',
#   'salt',
#   'preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'assemble',
#   'spread',
#   'meat',
#   'sauce',
#   'x',
#   'inch',
#   'baking',
#   'dish',
#   'arrange',
#   'noodles',
#   'lengthwise',
#   'meat',
#   'sauce',
#   'spread',
#   'half',
#   'ricotta',
#   'cheese',
#   'mixture',
#   'mozzarella',
#   'cheese',
#   'slices',
#   'spoon',
#   'meat',
#   'sauce',
#   'mozzarella',
#   'sprinkle',
#   'parmesan',
#   'cheese',
#   'repeat',
#   'layers',
#   'remaining',
#   'mozzarella',
#   'parmesan',
#   'cheese',
#   'cover',
#   'foil',
#   'prevent',
#   'sticking',
#   'spray',
#   'foil',
#   'cooking',
#   'spray',
#   'sure',
#   'foil',
#   'touch',
#   'cheese',
#   'bake',
#   'preheated',
#   'oven',
#   'minutes',
#   'remove',
#   'foil',
#   'bake',
#   'additional',
#   'minutes',
#   'cool',
#   'minutes',
#   'serving'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'grease',
#   'flour',
#   'inch',
#   'square',
#   'pan',
#   'large',
#   'saucepan',
#   'melt',
#   'butter',
#   'remove',
#   'heat',
#   'stir',
#   'sugar',
#   'eggs',
#   'vanilla',
#   'beat',
#   'cocoa',
#   'flour',
#   'salt',
#   'baking',
#   'powder',
#   'spread',
#   'batter',
#   'prepared',
#   'pan',
#   'bake',
#   'preheated',
#   'oven',
#   'minutes',
#   'overcook',
#   'frosting',
#   'combine',
#   's',
#   'butter',
#   's',
#   'cocoa',
#   'honey',
#   'vanilla',
#   'extract',
#   'confectioners',
#   'sugar',
#   'stir',
#   'smooth',
#   'frost',
#   'brownies',
#   'warm'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'grease',
#   'inch',
#   'round',
#   'cast',
#   'iron',
#   'skillet',
#   'inch',
#   'round',
#   'baking',
#   'cake',
#   'pan',
#   'mixing',
#   'bowl',
#   'combine',
#   'flour',
#   'reserving',
#   'sugar',
#   'baking',
#   'powder',
#   'baking',
#   'soda',
#   'salt',
#   'raisins',
#   'caraway',
#   'seeds',
#   'small',
#   'bowl',
#   'blend',
#   'eggs',
#   'buttermilk',
#   'sour',
#   'cream',
#   'stir',
#   'liquid',
#   'mixture',
#   'flour',
#   'mixture',
#   'flour',
#   'moistened',
#   'knead',
#   'dough',
#   'bowl',
#   'strokes',
#   'dough',
#   'sticky',
#   'place',
#   'dough',
#   'prepared',
#   'skillet',
#   'pan',
#   'pat',
#   'cut',
#   'x',
#   'inch',
#   'deep',
#   'slit',
#   'bread',
#   'dust',
#   'reserved',
#   'flour',
#   'bake',
#   'preheated',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'oven',
#   'minutes',
#   'let',
#   'cool',
#   'turn',
#   'bread',
#   'wire',
#   'rack'],
#  ['combine',
#   'potatoes',
#   'celery',
#   'onion',
#   'ham',
#   'water',
#   'stockpot',
#   'bring',
#   'boil',
#   'cook',
#   'medium',
#   'heat',
#   'potatoes',
#   'tender',
#   'minutes',
#   'stir',
#   'chicken',
#   'bouillon',
#   'salt',
#   'pepper',
#   'separate',
#   'saucepan',
#   'melt',
#   'butter',
#   'medium',
#   'low',
#   'heat',
#   'whisk',
#   'flour',
#   'fork',
#   'cook',
#   'stirring',
#   'constantly',
#   'minute',
#   'slowly',
#   'stir',
#   'milk',
#   'allow',
#   'lumps',
#   'form',
#   'milk',
#   'added',
#   'continue',
#   'stirring',
#   'medium',
#   'low',
#   'heat',
#   'minutes',
#   'stir',
#   'milk',
#   'mixture',
#   'stockpot',
#   'cook',
#   'soup',
#   'heated',
#   'serve',
#   'immediately'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'saucepan',
#   'combine',
#   'chicken',
#   'carrots',
#   'peas',
#   'celery',
#   'add',
#   'water',
#   'cover',
#   'boil',
#   'minutes',
#   'remove',
#   'heat',
#   'drain',
#   'set',
#   'aside',
#   'saucepan',
#   'medium',
#   'heat',
#   'cook',
#   'onions',
#   'butter',
#   'soft',
#   'translucent',
#   'stir',
#   'flour',
#   'salt',
#   'pepper',
#   'celery',
#   'seed',
#   'slowly',
#   'stir',
#   'chicken',
#   'broth',
#   'milk',
#   'simmer',
#   'medium',
#   'low',
#   'heat',
#   'remove',
#   'heat',
#   'set',
#   'aside',
#   'place',
#   'chicken',
#   'mixture',
#   'pie',
#   'crust',
#   'pour',
#   'hot',
#   'liquid',
#   'mixture',
#   'cover',
#   'crust',
#   'seal',
#   'edges',
#   'cut',
#   'away',
#   'excess',
#   'dough',
#   'small',
#   'slits',
#   'allow',
#   'steam',
#   'escape',
#   'bake',
#   'preheated',
#   'oven',
#   'minutes',
#   'pastry',
#   'golden',
#   'brown',
#   'filling',
#   'bubbly',
#   'cool',
#   'minutes',
#   'serving'],
#  ['combine',
#   'milk',
#   'vinegar',
#   'medium',
#   'bowl',
#   'set',
#   'aside',
#   'minutes',
#   'sour',
#   'combine',
#   'flour',
#   'sugar',
#   'baking',
#   'powder',
#   'baking',
#   'soda',
#   'salt',
#   'large',
#   'mixing',
#   'bowl',
#   'whisk',
#   'egg',
#   'butter',
#   'soured',
#   'milk',
#   'pour',
#   'flour',
#   'mixture',
#   'wet',
#   'ingredients',
#   'whisk',
#   'lumps',
#   'gone',
#   'heat',
#   'large',
#   'skillet',
#   'medium',
#   'heat',
#   'coat',
#   'cooking',
#   'spray',
#   'pour',
#   'fuls',
#   'batter',
#   'skillet',
#   'cook',
#   'bubbles',
#   'appear',
#   'surface',
#   'flip',
#   'spatula',
#   'cook',
#   'browned'],
#  ['large',
#   'bowl',
#   'sift',
#   'flour',
#   'baking',
#   'powder',
#   'salt',
#   'sugar',
#   'center',
#   'pour',
#   'milk',
#   'egg',
#   'melted',
#   'butter',
#   'mix',
#   'smooth',
#   'heat',
#   'lightly',
#   'oiled',
#   'griddle',
#   'frying',
#   'pan',
#   'medium',
#   'high',
#   'heat',
#   'pour',
#   'scoop',
#   'batter',
#   'griddle',
#   'approximately',
#   'pancake',
#   'brown',
#   'sides',
#   'serve',
#   'hot'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'lightly',
#   'grease',
#   'muffin',
#   'line',
#   'muffin',
#   'papers',
#   'large',
#   'bowl',
#   'mix',
#   'flour',
#   'baking',
#   'soda',
#   'baking',
#   'powder',
#   'salt',
#   'bowl',
#   'beat',
#   'bananas',
#   'sugar',
#   'egg',
#   'melted',
#   'butter',
#   'stir',
#   'banana',
#   'mixture',
#   'flour',
#   'mixture',
#   'moistened',
#   'spoon',
#   'batter',
#   'prepared',
#   'muffin',
#   'small',
#   'bowl',
#   'mix',
#   'brown',
#   'sugar',
#   's',
#   'flour',
#   'cinnamon',
#   'cut',
#   'butter',
#   'mixture',
#   'resembles',
#   'coarse',
#   'cornmeal',
#   'sprinkle',
#   'topping',
#   'muffins',
#   'bake',
#   'preheated',
#   'oven',
#   'minutes',
#   'toothpick',
#   'inserted',
#   'center',
#   'muffin',
#   'comes',
#   'clean'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'butter',
#   'x',
#   'inch',
#   'jelly',
#   'roll',
#   'pan',
#   'place',
#   'fudge',
#   'brownie',
#   'mix',
#   'large',
#   'bowl',
#   'beat',
#   'irish',
#   'cream',
#   'liqueur',
#   'vegetable',
#   'oil',
#   'eggs',
#   'mixture',
#   'forms',
#   'smooth',
#   'batter',
#   'spread',
#   'batter',
#   'prepared',
#   'jelly',
#   'roll',
#   'pan',
#   'bake',
#   'preheated',
#   'oven',
#   'brownies',
#   'set',
#   'toothpick',
#   'inserted',
#   'center',
#   'comes',
#   'clean',
#   'minutes',
#   'remove',
#   'pan',
#   'oven',
#   'allow',
#   'cool',
#   'completely',
#   'beat',
#   'unsalted',
#   'butter',
#   'large',
#   'bowl',
#   'smooth',
#   'beat',
#   's',
#   'irish',
#   'cream',
#   'liqueur',
#   'mixture',
#   'creamy',
#   'slowly',
#   'beat',
#   'confectioners',
#   'sugar',
#   'time',
#   'frosting',
#   'desired',
#   'stiffness',
#   'spread',
#   'frosting',
#   'brownies',
#   'serve'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'melt',
#   'butter',
#   'saucepan',
#   'stir',
#   'flour',
#   'form',
#   'paste',
#   'add',
#   'water',
#   'white',
#   'sugar',
#   'brown',
#   'sugar',
#   'bring',
#   'boil',
#   'reduce',
#   'temperature',
#   'let',
#   'simmer',
#   'place',
#   'crust',
#   'pan',
#   'apples',
#   'mounded',
#   'slightly',
#   'cover',
#   'lattice',
#   'work',
#   'crust',
#   'gently',
#   'pour',
#   'sugar',
#   'butter',
#   'liquid',
#   'crust',
#   'pour',
#   'slowly',
#   'run',
#   'bake',
#   'minutes',
#   'preheated',
#   'oven',
#   'reduce',
#   'temperature',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'continue',
#   'baking',
#   'minutes',
#   'apples',
#   'soft'],
#  ['place',
#   'potatoes',
#   'cabbage',
#   'green',
#   'onions',
#   'large',
#   'sauce',
#   'pan',
#   'water',
#   'bring',
#   'boil',
#   'reduce',
#   'heat',
#   'cover',
#   'simmer',
#   'potatoes',
#   'tender',
#   'minutes',
#   'drain',
#   'vegetables',
#   'place',
#   'large',
#   'bowl',
#   'mash',
#   'potatoes',
#   'vegetables',
#   'butter',
#   'fork',
#   'mixture',
#   'chunky',
#   'pouring',
#   'half',
#   'half',
#   'gradually',
#   'mash',
#   'season',
#   'salt',
#   'pepper',
#   'serve'],
#  ['whisk',
#   'maple',
#   'syrup',
#   'balsamic',
#   'vinegar',
#   'garlic',
#   'powder',
#   'cayenne',
#   'pepper',
#   'white',
#   'pepper',
#   'nutmeg',
#   'chipotle',
#   'pepper',
#   'small',
#   'bowl',
#   'rub',
#   'smooth',
#   'coat',
#   'chicken',
#   'sides',
#   'rub',
#   'heat',
#   'olive',
#   'oil',
#   'large',
#   'skillet',
#   'medium',
#   'high',
#   'heat',
#   'cook',
#   'chicken',
#   'hot',
#   'oil',
#   'longer',
#   'pink',
#   'center',
#   'juices',
#   'run',
#   'clear',
#   'minutes',
#   'instant',
#   'read',
#   'thermometer',
#   'inserted',
#   'center',
#   'read',
#   'degrees',
#   'f',
#   'degrees',
#   'c'],
#  ['place',
#   'chicken',
#   'slow',
#   'cooker',
#   'bowl',
#   'mix',
#   'barbecue',
#   'sauce',
#   'italian',
#   'salad',
#   'dressing',
#   'brown',
#   'sugar',
#   'worcestershire',
#   'sauce',
#   'pour',
#   'chicken',
#   'cover',
#   'cook',
#   'hours',
#   'high',
#   'hours',
#   'low'],
#  ['chicken',
#   'breasts',
#   'place',
#   'cheese',
#   'ham',
#   'slice',
#   'breast',
#   'inch',
#   'edges',
#   'fold',
#   'edges',
#   'chicken',
#   'filling',
#   'secure',
#   'toothpicks',
#   'mix',
#   'flour',
#   'paprika',
#   'small',
#   'bowl',
#   'coat',
#   'chicken',
#   'pieces',
#   'heat',
#   'butter',
#   'large',
#   'skillet',
#   'medium',
#   'high',
#   'heat',
#   'cook',
#   'chicken',
#   'browned',
#   'sides',
#   'add',
#   'wine',
#   'bouillon',
#   'reduce',
#   'heat',
#   'low',
#   'cover',
#   'simmer',
#   'minutes',
#   'chicken',
#   'longer',
#   'pink',
#   'juices',
#   'run',
#   'clear',
#   'remove',
#   'toothpicks',
#   'transfer',
#   'breasts',
#   'warm',
#   'platter',
#   'blend',
#   'cornstarch',
#   'cream',
#   'small',
#   'bowl',
#   'whisk',
#   'slowly',
#   'skillet',
#   'cook',
#   'stirring',
#   'thickened',
#   'pour',
#   'chicken',
#   'serve',
#   'warm'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'grease',
#   'inch',
#   'springform',
#   'pan',
#   'medium',
#   'bowl',
#   'mix',
#   'graham',
#   'cracker',
#   'crumbs',
#   'melted',
#   'butter',
#   'press',
#   'springform',
#   'pan',
#   'large',
#   'bowl',
#   'mix',
#   'cream',
#   'cheese',
#   'sugar',
#   'smooth',
#   'blend',
#   'milk',
#   'mix',
#   'eggs',
#   'time',
#   'mixing',
#   'incorporate',
#   'mix',
#   'sour',
#   'cream',
#   'vanilla',
#   'flour',
#   'smooth',
#   'pour',
#   'filling',
#   'prepared',
#   'crust',
#   'bake',
#   'preheated',
#   'oven',
#   'hour',
#   'turn',
#   'oven',
#   'let',
#   'cake',
#   'cool',
#   'oven',
#   'door',
#   'closed',
#   'hours',
#   'prevents',
#   'cracking',
#   'chill',
#   'refrigerator',
#   'serving'],
#  ['small',
#   'saucepan',
#   'low',
#   'heat',
#   'combine',
#   'cornstarch',
#   'cold',
#   'water',
#   'sugar',
#   'soy',
#   'sauce',
#   'vinegar',
#   'garlic',
#   'ginger',
#   'ground',
#   'black',
#   'pepper',
#   'let',
#   'simmer',
#   'stirring',
#   'frequently',
#   'sauce',
#   'thickens',
#   'bubbles',
#   'preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'place',
#   'chicken',
#   'pieces',
#   'lightly',
#   'greased',
#   'x',
#   'inch',
#   'baking',
#   'dish',
#   'brush',
#   'chicken',
#   'sauce',
#   'turn',
#   'pieces',
#   'brush',
#   'bake',
#   'preheated',
#   'oven',
#   'minutes',
#   'turn',
#   'pieces',
#   'bake',
#   'minutes',
#   'longer',
#   'pink',
#   'juices',
#   'run',
#   'clear',
#   'brush',
#   'sauce',
#   'minutes',
#   'cooking'],
#  ['medium',
#   'bowl',
#   'mash',
#   'avocados',
#   'lime',
#   'juice',
#   'salt',
#   'mix',
#   'onion',
#   'cilantro',
#   'tomatoes',
#   'garlic',
#   'stir',
#   'cayenne',
#   'pepper',
#   'refrigerate',
#   'hour',
#   'best',
#   'flavor',
#   'serve',
#   'immediately'],
#  ['heat',
#   'large',
#   'stock',
#   'pot',
#   'medium',
#   'high',
#   'heat',
#   'crumble',
#   'ground',
#   'chuck',
#   'sausage',
#   'hot',
#   'pan',
#   'cook',
#   'evenly',
#   'browned',
#   'drain',
#   'excess',
#   'grease',
#   'pour',
#   'chili',
#   'beans',
#   'spicy',
#   'chili',
#   'beans',
#   'diced',
#   'tomatoes',
#   'tomato',
#   'paste',
#   'add',
#   'onion',
#   'celery',
#   'green',
#   'red',
#   'bell',
#   'peppers',
#   'chile',
#   'peppers',
#   'bacon',
#   'bits',
#   'bouillon',
#   'beer',
#   'season',
#   'chili',
#   'powder',
#   'worcestershire',
#   'sauce',
#   'garlic',
#   'oregano',
#   'cumin',
#   'hot',
#   'pepper',
#   'sauce',
#   'basil',
#   'salt',
#   'pepper',
#   'cayenne',
#   'paprika',
#   'sugar',
#   'stir',
#   'blend',
#   'cover',
#   'simmer',
#   'low',
#   'heat',
#   'hours',
#   'stirring',
#   'occasionally',
#   'hours',
#   'taste',
#   'adjust',
#   'salt',
#   'pepper',
#   'chili',
#   'powder',
#   'necessary',
#   'longer',
#   'chili',
#   'simmers',
#   'better',
#   'taste',
#   'remove',
#   'heat',
#   'serve',
#   'refrigerate',
#   'serve',
#   'day',
#   'serve',
#   'ladle',
#   'bowls',
#   'corn',
#   'chips',
#   'shredded',
#   'cheddar',
#   'cheese'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'rinse',
#   'pork',
#   'chops',
#   'pat',
#   'dry',
#   'season',
#   'garlic',
#   'powder',
#   'seasoning',
#   'salt',
#   'taste',
#   'place',
#   'beaten',
#   'eggs',
#   'small',
#   'bowl',
#   'dredge',
#   'pork',
#   'chops',
#   'lightly',
#   'flour',
#   'dip',
#   'egg',
#   'coat',
#   'liberally',
#   'bread',
#   'crumbs',
#   'heat',
#   'oil',
#   'medium',
#   'skillet',
#   'medium',
#   'high',
#   'heat',
#   'fry',
#   'pork',
#   'chops',
#   'minutes',
#   'breading',
#   'appears',
#   'browned',
#   'transfer',
#   'chops',
#   'x',
#   'inch',
#   'baking',
#   'dish',
#   'cover',
#   'foil',
#   'bake',
#   'preheated',
#   'oven',
#   'hour',
#   'baking',
#   'combine',
#   'cream',
#   'mushroom',
#   'soup',
#   'milk',
#   'white',
#   'wine',
#   'medium',
#   'bowl',
#   'pork',
#   'chops',
#   'baked',
#   'hour',
#   'cover',
#   'soup',
#   'mixture',
#   'replace',
#   'foil',
#   'bake',
#   'minutes'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'small',
#   'bowl',
#   'stir',
#   'flour',
#   'baking',
#   'soda',
#   'baking',
#   'powder',
#   'set',
#   'aside',
#   'large',
#   'bowl',
#   'cream',
#   'butter',
#   'sugar',
#   'smooth',
#   'beat',
#   'egg',
#   'vanilla',
#   'gradually',
#   'blend',
#   'dry',
#   'ingredients',
#   'roll',
#   'rounded',
#   'fuls',
#   'dough',
#   'balls',
#   'place',
#   'ungreased',
#   'cookie',
#   'sheets',
#   'bake',
#   'minutes',
#   'preheated',
#   'oven',
#   'golden',
#   'let',
#   'stand',
#   'cookie',
#   'sheet',
#   'minutes',
#   'removing',
#   'cool',
#   'wire',
#   'racks'],
#  ['place',
#   'onion',
#   'chili',
#   'beans',
#   'black',
#   'beans',
#   'corn',
#   'tomato',
#   'sauce',
#   'beer',
#   'diced',
#   'tomatoes',
#   'slow',
#   'cooker',
#   'add',
#   'taco',
#   'seasoning',
#   'stir',
#   'blend',
#   'lay',
#   'chicken',
#   'breasts',
#   'mixture',
#   'pressing',
#   'slightly',
#   'covered',
#   'ingredients',
#   'set',
#   'slow',
#   'cooker',
#   'low',
#   'heat',
#   'cover',
#   'cook',
#   'hours',
#   'remove',
#   'chicken',
#   'breasts',
#   'soup',
#   'allow',
#   'cool',
#   'long',
#   'handled',
#   'stir',
#   'shredded',
#   'chicken',
#   'soup',
#   'continue',
#   'cooking',
#   'hours',
#   'serve',
#   'topped',
#   'shredded',
#   'cheddar',
#   'cheese',
#   'dollop',
#   'sour',
#   'cream',
#   'tortilla',
#   'chips',
#   'desired'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'grease',
#   'inch',
#   'square',
#   'pan',
#   'melt',
#   'butter',
#   'large',
#   'skillet',
#   'remove',
#   'heat',
#   'stir',
#   'sugar',
#   'quickly',
#   'add',
#   'eggs',
#   'beat',
#   'blended',
#   'combine',
#   'buttermilk',
#   'baking',
#   'soda',
#   'stir',
#   'mixture',
#   'pan',
#   'stir',
#   'cornmeal',
#   'flour',
#   'salt',
#   'blended',
#   'lumps',
#   'remain',
#   'pour',
#   'batter',
#   'prepared',
#   'pan',
#   'bake',
#   'preheated',
#   'oven',
#   'minutes',
#   'toothpick',
#   'inserted',
#   'center',
#   'comes',
#   'clean'],
#  ['bring',
#   'large',
#   'pot',
#   'lightly',
#   'salted',
#   'water',
#   'boil',
#   'add',
#   'ziti',
#   'pasta',
#   'cook',
#   'al',
#   'dente',
#   'minutes',
#   'drain',
#   'large',
#   'skillet',
#   'brown',
#   'onion',
#   'ground',
#   'beef',
#   'medium',
#   'heat',
#   'add',
#   'spaghetti',
#   'sauce',
#   'simmer',
#   'minutes',
#   'preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'butter',
#   'x',
#   'inch',
#   'baking',
#   'dish',
#   'layer',
#   'follows',
#   'ziti',
#   'provolone',
#   'cheese',
#   'sour',
#   'cream',
#   'sauce',
#   'mixture',
#   'remaining',
#   'ziti',
#   'mozzarella',
#   'cheese',
#   'remaining',
#   'sauce',
#   'mixture',
#   'grated',
#   'parmesan',
#   'cheese',
#   'bake',
#   'minutes',
#   'preheated',
#   'oven',
#   'cheeses',
#   'melted'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'grease',
#   'x',
#   'inch',
#   'loaf',
#   'pan',
#   'large',
#   'bowl',
#   'stir',
#   'melted',
#   'butter',
#   'sugar',
#   'add',
#   'eggs',
#   'vanilla',
#   'mix',
#   'combine',
#   'flour',
#   'baking',
#   'soda',
#   'salt',
#   'stir',
#   'butter',
#   'mixture',
#   'smooth',
#   'finally',
#   'fold',
#   'sour',
#   'cream',
#   'walnuts',
#   'bananas',
#   'spread',
#   'evenly',
#   'prepared',
#   'pan',
#   'bake',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'minutes',
#   'toothpick',
#   'inserted',
#   'center',
#   'loaf',
#   'comes',
#   'clean',
#   'cool',
#   'loaf',
#   'pan',
#   'minutes',
#   'removing',
#   'wire',
#   'rack',
#   'cool',
#   'completely'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'sift',
#   'flour',
#   'ginger',
#   'baking',
#   'soda',
#   'cinnamon',
#   'cloves',
#   'salt',
#   'set',
#   'aside',
#   'large',
#   'bowl',
#   'cream',
#   'margarine',
#   'sugar',
#   'light',
#   'fluffy',
#   'beat',
#   'egg',
#   'stir',
#   'water',
#   'molasses',
#   'gradually',
#   'stir',
#   'sifted',
#   'ingredients',
#   'molasses',
#   'mixture',
#   'shape',
#   'dough',
#   'walnut',
#   'sized',
#   'balls',
#   'roll',
#   'remaining',
#   's',
#   'sugar',
#   'place',
#   'cookies',
#   'inches',
#   'apart',
#   'ungreased',
#   'cookie',
#   'sheet',
#   'flatten',
#   'slightly',
#   'bake',
#   'minutes',
#   'preheated',
#   'oven',
#   'allow',
#   'cookies',
#   'cool',
#   'baking',
#   'sheet',
#   'minutes',
#   'removing',
#   'wire',
#   'rack',
#   'cool',
#   'completely',
#   'store',
#   'airtight',
#   'container'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'cream',
#   'butter',
#   'shortening',
#   'sugar',
#   'eggs',
#   'vanilla',
#   'blend',
#   'flour',
#   'cream',
#   'tartar',
#   'soda',
#   'salt',
#   'shape',
#   'dough',
#   'rounded',
#   'spoonfuls',
#   'balls',
#   'mix',
#   's',
#   'sugar',
#   'cinnamon',
#   'roll',
#   'balls',
#   'dough',
#   'mixture',
#   'place',
#   'inches',
#   'apart',
#   'ungreased',
#   'baking',
#   'sheets',
#   'bake',
#   'minutes',
#   'set',
#   'hard',
#   'remove',
#   'immediately',
#   'baking',
#   'sheets'],
#  ['small',
#   'bowl',
#   'mix',
#   'chili',
#   'powder',
#   'garlic',
#   'powder',
#   'onion',
#   'powder',
#   'red',
#   'pepper',
#   'flakes',
#   'oregano',
#   'paprika',
#   'cumin',
#   'salt',
#   'pepper',
#   'store',
#   'airtight',
#   'container'],
#  ['medium',
#   'skillet',
#   'medium',
#   'heat',
#   'brown',
#   'ground',
#   'beef',
#   'onion',
#   'green',
#   'pepper',
#   'drain',
#   'liquids',
#   'stir',
#   'garlic',
#   'powder',
#   'mustard',
#   'ketchup',
#   'brown',
#   'sugar',
#   'mix',
#   'thoroughly',
#   'reduce',
#   'heat',
#   'simmer',
#   'minutes',
#   'season',
#   'salt',
#   'pepper'],
#  ['place',
#   'ingredients',
#   'pan',
#   'bread',
#   'machine',
#   'order',
#   'recommended',
#   'manufacturer',
#   'select',
#   'dough',
#   'cycle',
#   'press',
#   'start',
#   'dough',
#   'doubled',
#   'size',
#   'turn',
#   'lightly',
#   'floured',
#   'surface',
#   'cover',
#   'let',
#   'rest',
#   'minutes',
#   'small',
#   'bowl',
#   'combine',
#   'brown',
#   'sugar',
#   'cinnamon',
#   'roll',
#   'dough',
#   'x',
#   'inch',
#   'rectangle',
#   'spread',
#   'dough',
#   'butter',
#   'sprinkle',
#   'evenly',
#   'sugarcinnamon',
#   'mixture',
#   'roll',
#   'dough',
#   'cut',
#   'rolls',
#   'place',
#   'rolls',
#   'lightly',
#   'greased',
#   'x',
#   'inch',
#   'baking',
#   'pan',
#   'cover',
#   'let',
#   'rise',
#   'nearly',
#   'doubled',
#   'minutes',
#   'preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'bake',
#   'rolls',
#   'preheated',
#   'oven',
#   'golden',
#   'brown',
#   'minutes',
#   'rolls',
#   'baking',
#   'beat',
#   'cream',
#   'cheese',
#   'butter',
#   'confectioners',
#   'sugar',
#   'vanilla',
#   'extract',
#   'salt',
#   'spread',
#   'frosting',
#   'warm',
#   'rolls',
#   'serving'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'large',
#   'bowl',
#   'mix',
#   'cake',
#   'pudding',
#   'mixes',
#   'sour',
#   'cream',
#   'oil',
#   'beaten',
#   'eggs',
#   'water',
#   'stir',
#   'chocolate',
#   'chips',
#   'pour',
#   'batter',
#   'greased',
#   'bundt',
#   'pan',
#   'bake',
#   'minutes',
#   'springy',
#   'touch',
#   'wooden',
#   'toothpick',
#   'inserted',
#   'comes',
#   'clean',
#   'cool',
#   'cake',
#   'thoroughly',
#   'pan',
#   'hour',
#   'half',
#   'inverting',
#   'plate',
#   'desired',
#   'dust',
#   'cake',
#   'powdered',
#   'sugar'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'grease',
#   'flour',
#   'x',
#   'inch',
#   'pan',
#   'large',
#   'bowl',
#   'beat',
#   'eggs',
#   'oil',
#   'white',
#   'sugar',
#   's',
#   'vanilla',
#   'mix',
#   'flour',
#   'baking',
#   'soda',
#   'baking',
#   'powder',
#   'salt',
#   'cinnamon',
#   'stir',
#   'carrots',
#   'fold',
#   'pecans',
#   'pour',
#   'prepared',
#   'pan',
#   'bake',
#   'preheated',
#   'oven',
#   'minutes',
#   'toothpick',
#   'inserted',
#   'center',
#   'cake',
#   'comes',
#   'clean',
#   'let',
#   'cool',
#   'pan',
#   'minutes',
#   'turn',
#   'wire',
#   'rack',
#   'cool',
#   'completely',
#   'frosting',
#   'medium',
#   'bowl',
#   'combine',
#   'butter',
#   'cream',
#   'cheese',
#   'confectioners',
#   'sugar',
#   'vanilla',
#   'beat',
#   'mixture',
#   'smooth',
#   'creamy',
#   'stir',
#   'pecans',
#   'frost',
#   'cooled',
#   'cake'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degree',
#   'c',
#   'place',
#   'sliced',
#   'apples',
#   'x',
#   'inch',
#   'pan',
#   'mix',
#   'white',
#   'sugar',
#   'flour',
#   'ground',
#   'cinnamon',
#   'sprinkle',
#   'apples',
#   'pour',
#   'water',
#   'evenly',
#   'combine',
#   'oats',
#   'flour',
#   'brown',
#   'sugar',
#   'baking',
#   'powder',
#   'baking',
#   'soda',
#   'melted',
#   'butter',
#   'crumble',
#   'evenly',
#   'apple',
#   'mixture',
#   'bake',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'minutes'],
#  ['large',
#   'bowl',
#   'dissolve',
#   'sugar',
#   'warm',
#   'water',
#   'stir',
#   'yeast',
#   'allow',
#   'proof',
#   'yeast',
#   'resembles',
#   'creamy',
#   'foam',
#   'mix',
#   'salt',
#   'oil',
#   'yeast',
#   'mix',
#   'flour',
#   'time',
#   'knead',
#   'dough',
#   'lightly',
#   'floured',
#   'surface',
#   'smooth',
#   'place',
#   'oiled',
#   'bowl',
#   'turn',
#   'dough',
#   'coat',
#   'cover',
#   'damp',
#   'cloth',
#   'allow',
#   'rise',
#   'doubled',
#   'bulk',
#   'hour',
#   'punch',
#   'dough',
#   'knead',
#   'minutes',
#   'divide',
#   'half',
#   'shape',
#   'loaves',
#   'place',
#   'oiled',
#   'x',
#   'inch',
#   'loaf',
#   'pans',
#   'allow',
#   'rise',
#   'minutes',
#   'dough',
#   'risen',
#   'inch',
#   'pans',
#   'bake',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'minutes'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'butter',
#   'quart',
#   'casserole',
#   'dish',
#   'layer',
#   'potatoes',
#   'prepared',
#   'casserole',
#   'dish',
#   'onion',
#   'slices',
#   'add',
#   'remaining',
#   'potatoes',
#   'season',
#   'salt',
#   'pepper',
#   'taste',
#   'medium',
#   'size',
#   'saucepan',
#   'melt',
#   'butter',
#   'medium',
#   'heat',
#   'mix',
#   'flour',
#   'salt',
#   'stir',
#   'constantly',
#   'whisk',
#   'minute',
#   'stir',
#   'milk',
#   'cook',
#   'mixture',
#   'thickened',
#   'stir',
#   'cheese',
#   'continue',
#   'stirring',
#   'melted',
#   'seconds',
#   'pour',
#   'cheese',
#   'potatoes',
#   'cover',
#   'dish',
#   'aluminum',
#   'foil',
#   'bake',
#   'hours',
#   'preheated',
#   'oven'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'heat',
#   'olive',
#   'oil',
#   'garlic',
#   'small',
#   'saucepan',
#   'low',
#   'heat',
#   'warmed',
#   'minutes',
#   'transfer',
#   'garlic',
#   'oil',
#   'shallow',
#   'bowl',
#   'combine',
#   'bread',
#   'crumbs',
#   'parmesan',
#   'cheese',
#   'separate',
#   'shallow',
#   'bowl',
#   'dip',
#   'chicken',
#   'breasts',
#   'olive',
#   'oil',
#   'garlic',
#   'mixture',
#   'tongs',
#   'transfer',
#   'bread',
#   'crumb',
#   'mixture',
#   'turn',
#   'evenly',
#   'coat',
#   'transfer',
#   'coated',
#   'chicken',
#   'shallow',
#   'baking',
#   'dish',
#   'bake',
#   'preheated',
#   'oven',
#   'longer',
#   'pink',
#   'juices',
#   'run',
#   'clear',
#   'minutes',
#   'instant',
#   'read',
#   'thermometer',
#   'inserted',
#   'center',
#   'read',
#   'degrees',
#   'f',
#   'degrees',
#   'c'],
#  ['season',
#   'salmon',
#   'fillets',
#   'lemon',
#   'pepper',
#   'garlic',
#   'powder',
#   'salt',
#   'small',
#   'bowl',
#   'stir',
#   'soy',
#   'sauce',
#   'brown',
#   'sugar',
#   'water',
#   'vegetable',
#   'oil',
#   'sugar',
#   'dissolved',
#   'place',
#   'fish',
#   'large',
#   'resealable',
#   'plastic',
#   'bag',
#   'soy',
#   'sauce',
#   'mixture',
#   'seal',
#   'turn',
#   'coat',
#   'refrigerate',
#   'hours',
#   'preheat',
#   'grill',
#   'medium',
#   'heat',
#   'lightly',
#   'oil',
#   'grill',
#   'grate',
#   'place',
#   'salmon',
#   'preheated',
#   'grill',
#   'discard',
#   'marinade',
#   'cook',
#   'salmon',
#   'minutes',
#   'fish',
#   'flakes',
#   'easily',
#   'fork'],
#  ['heat',
#   'chicken',
#   'hot',
#   'sauce',
#   'skillet',
#   'medium',
#   'heat',
#   'heated',
#   'stir',
#   'cream',
#   'cheese',
#   'ranch',
#   'dressing',
#   'cook',
#   'stirring',
#   'blended',
#   'warm',
#   'mix',
#   'half',
#   'shredded',
#   'cheese',
#   'transfer',
#   'mixture',
#   'slow',
#   'cooker',
#   'sprinkle',
#   'remaining',
#   'cheese',
#   'cover',
#   'cook',
#   'low',
#   'setting',
#   'hot',
#   'bubbly',
#   'serve',
#   'celery',
#   'sticks',
#   'crackers'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'place',
#   'chicken',
#   'breasts',
#   'lightly',
#   'greased',
#   'x',
#   'inch',
#   'baking',
#   'dish',
#   'sprinkle',
#   'taco',
#   'seasoning',
#   'sides',
#   'chicken',
#   'breasts',
#   'pour',
#   'salsa',
#   'bake',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'minutes',
#   'chicken',
#   'tender',
#   'juicy',
#   'juices',
#   'run',
#   'clear',
#   'sprinkle',
#   'chicken',
#   'evenly',
#   'cheese',
#   'continue',
#   'baking',
#   'additional',
#   'minutes',
#   'cheese',
#   'melted',
#   'bubbly',
#   'sour',
#   'cream',
#   'desired',
#   'serve'],
#  ['melt',
#   'butter',
#   'medium',
#   'non',
#   'stick',
#   'saucepan',
#   'medium',
#   'heat',
#   'add',
#   'cream',
#   'cheese',
#   'garlic',
#   'powder',
#   'stirring',
#   'wire',
#   'whisk',
#   'smooth',
#   'add',
#   'milk',
#   'little',
#   'time',
#   'whisking',
#   'smooth',
#   'lumps',
#   'stir',
#   'parmesan',
#   'pepper',
#   'remove',
#   'heat',
#   'sauce',
#   'reaches',
#   'desired',
#   'consistency',
#   'sauce',
#   'thicken',
#   'rapidly',
#   'milk',
#   'cooked',
#   'long',
#   'toss',
#   'hot',
#   'pasta',
#   'serve'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'large',
#   'bowl',
#   'cream',
#   'butter',
#   'brown',
#   'sugar',
#   'white',
#   'sugar',
#   'smooth',
#   'beat',
#   'eggs',
#   'time',
#   'stir',
#   'vanilla',
#   'combine',
#   'flour',
#   'baking',
#   'soda',
#   'salt',
#   'stir',
#   'creamed',
#   'mixture',
#   'blended',
#   'mix',
#   'quick',
#   'oats',
#   'walnuts',
#   'chocolate',
#   'chips',
#   'drop',
#   'heaping',
#   'spoonfuls',
#   'ungreased',
#   'baking',
#   'sheets',
#   'bake',
#   'minutes',
#   'preheated',
#   'oven',
#   'allow',
#   'cookies',
#   'cool',
#   'baking',
#   'sheet',
#   'minutes',
#   'transferring',
#   'wire',
#   'rack',
#   'cool',
#   'completely'],
#  ['shallow',
#   'dish',
#   'bowl',
#   'mix',
#   'flour',
#   'salt',
#   'pepper',
#   'oregano',
#   'coat',
#   'chicken',
#   'pieces',
#   'flour',
#   'mixture',
#   'large',
#   'skillet',
#   'melt',
#   'butter',
#   'oil',
#   'medium',
#   'heat',
#   'place',
#   'chicken',
#   'pan',
#   'lightly',
#   'brown',
#   'turn',
#   'chicken',
#   'pieces',
#   'add',
#   'mushrooms',
#   'pour',
#   'wine',
#   'sherry',
#   'cover',
#   'skillet',
#   'simmer',
#   'chicken',
#   'minutes',
#   'turning',
#   'longer',
#   'pink',
#   'juices',
#   'run',
#   'clear'],
#  ['place',
#   'chicken',
#   'tomatoes',
#   'enchilada',
#   'sauce',
#   'onion',
#   'green',
#   'chiles',
#   'garlic',
#   'slow',
#   'cooker',
#   'pour',
#   'water',
#   'chicken',
#   'broth',
#   'season',
#   'cumin',
#   'chili',
#   'powder',
#   'salt',
#   'pepper',
#   'bay',
#   'leaf',
#   'stir',
#   'corn',
#   'cilantro',
#   'cover',
#   'cook',
#   'low',
#   'setting',
#   'hours',
#   'high',
#   'setting',
#   'hours',
#   'preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'lightly',
#   'brush',
#   'sides',
#   'tortillas',
#   'oil',
#   'cut',
#   'tortillas',
#   'strips',
#   'spread',
#   'baking',
#   'sheet',
#   'bake',
#   'preheated',
#   'oven',
#   'crisp',
#   'minutes',
#   'serve',
#   'sprinkle',
#   'tortilla',
#   'strips',
#   'soup'],
#  ['bring',
#   'water',
#   'boil',
#   'saucepan',
#   'stir',
#   'rice',
#   'boiling',
#   'water',
#   'reduce',
#   'heat',
#   'low',
#   'cover',
#   'simmer',
#   'minutes',
#   'clean',
#   'saucepan',
#   'combine',
#   'cooked',
#   'rice',
#   'milk',
#   'sugar',
#   'salt',
#   'cook',
#   'medium',
#   'heat',
#   'creamy',
#   'minutes',
#   'stir',
#   'remaining',
#   'milk',
#   'beaten',
#   'egg',
#   'raisins',
#   'cook',
#   'minutes',
#   'stirring',
#   'constantly',
#   'remove',
#   'heat',
#   'stir',
#   'butter',
#   'vanilla'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'grease',
#   'x',
#   'inch',
#   'loaf',
#   'pans',
#   'small',
#   'bowl',
#   'stir',
#   'white',
#   'sugar',
#   'cinnamon',
#   'dust',
#   'pans',
#   'lightly',
#   'cinnamon',
#   'sugar',
#   'mixture',
#   'large',
#   'bowl',
#   'cream',
#   'butter',
#   'sugar',
#   'mix',
#   'eggs',
#   'mashed',
#   'bananas',
#   'sour',
#   'cream',
#   'vanilla',
#   'cinnamon',
#   'mix',
#   'salt',
#   'baking',
#   'soda',
#   'flour',
#   'stir',
#   'nuts',
#   'divide',
#   'prepared',
#   'pans',
#   'bake',
#   'hour',
#   'toothpick',
#   'inserted',
#   'center',
#   'comes',
#   'clean'],
#  ['heat',
#   'oil',
#   'saucepan',
#   'medium',
#   'heat',
#   'cook',
#   'stir',
#   'onion',
#   'garlic',
#   'lightly',
#   'browned',
#   'minutes',
#   'mix',
#   'quinoa',
#   'onion',
#   'mixture',
#   'cover',
#   'vegetable',
#   'broth',
#   'season',
#   'cumin',
#   'cayenne',
#   'pepper',
#   'salt',
#   'pepper',
#   'bring',
#   'mixture',
#   'boil',
#   'cover',
#   'reduce',
#   'heat',
#   'simmer',
#   'quinoa',
#   'tender',
#   'broth',
#   'absorbed',
#   'minutes',
#   'stir',
#   'frozen',
#   'corn',
#   'saucepan',
#   'continue',
#   'simmer',
#   'heated',
#   'minutes',
#   'mix',
#   'black',
#   'beans',
#   'cilantro'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'large',
#   'bowl',
#   'combine',
#   'beef',
#   'egg',
#   'onion',
#   'milk',
#   'bread',
#   'cracker',
#   'crumbs',
#   'season',
#   'salt',
#   'pepper',
#   'taste',
#   'place',
#   'lightly',
#   'greased',
#   'x',
#   'inch',
#   'loaf',
#   'pan',
#   'form',
#   'loaf',
#   'place',
#   'lightly',
#   'greased',
#   'x',
#   'inch',
#   'baking',
#   'dish',
#   'separate',
#   'small',
#   'bowl',
#   'combine',
#   'brown',
#   'sugar',
#   'mustard',
#   'ketchup',
#   'mix',
#   'pour',
#   'meatloaf',
#   'bake',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'hour'],
#  ['large',
#   'bowl',
#   'thoroughly',
#   'mix',
#   'kiwis',
#   'golden',
#   'delicious',
#   'apples',
#   'raspberries',
#   'strawberries',
#   'white',
#   'sugar',
#   'brown',
#   'sugar',
#   'fruit',
#   'preserves',
#   'cover',
#   'chill',
#   'refrigerator',
#   'minutes',
#   'preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'coat',
#   'flour',
#   'tortilla',
#   'butter',
#   'flavored',
#   'cooking',
#   'spray',
#   'cut',
#   'wedges',
#   'arrange',
#   'single',
#   'layer',
#   'large',
#   'baking',
#   'sheet',
#   'sprinkle',
#   'wedges',
#   'desired',
#   'cinnamon',
#   'sugar',
#   'spray',
#   'cooking',
#   'spray',
#   'bake',
#   'preheated',
#   'oven',
#   'minutes',
#   'repeat',
#   'remaining',
#   'tortilla',
#   'wedges',
#   'allow',
#   'cool',
#   'approximately',
#   'minutes',
#   'serve',
#   'chilled',
#   'fruit',
#   'mixture'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'lightly',
#   'grease',
#   'large',
#   'baking',
#   'dish',
#   'medium',
#   'saucepan',
#   'medium',
#   'heat',
#   'melt',
#   'butter',
#   'saute',
#   'green',
#   'onion',
#   'tender',
#   'minutes',
#   'add',
#   'garlic',
#   'powder',
#   'stir',
#   'green',
#   'chiles',
#   'cream',
#   'mushroom',
#   'soup',
#   'sour',
#   'cream',
#   'mix',
#   'reserve',
#   'sauce',
#   'set',
#   'aside',
#   'remaining',
#   'sauce',
#   'saucepan',
#   'add',
#   'chicken',
#   'shredded',
#   'cheddar',
#   'cheese',
#   'stir',
#   'flour',
#   'tortilla',
#   'chicken',
#   'mixture',
#   'roll',
#   'place',
#   'seam',
#   'prepared',
#   'baking',
#   'dish',
#   'small',
#   'bowl',
#   'combine',
#   'reserved',
#   'sauce',
#   'milk',
#   'spoon',
#   'mixture',
#   'rolled',
#   'tortillas',
#   'remaining',
#   'shredded',
#   'cheddar',
#   'cheese',
#   'bake',
#   'preheated',
#   'oven',
#   'minutes',
#   'cheese',
#   'bubbly'],
#  ['place',
#   'pork',
#   'tenderloin',
#   'slow',
#   'cooker',
#   'pour',
#   'root',
#   'beer',
#   'meat',
#   'cover',
#   'cook',
#   'low',
#   'cooked',
#   'pork',
#   'shreds',
#   'easily',
#   'hours',
#   'note',
#   'actual',
#   'length',
#   'time',
#   'vary',
#   'according',
#   'individual',
#   'slow',
#   'cooker',
#   'drain',
#   'stir',
#   'barbecue',
#   'sauce',
#   'serve',
#   'hamburger',
#   'buns'],
#  ['medium',
#   'bowl',
#   'cream',
#   'cream',
#   'cheese',
#   'butter',
#   'creamy',
#   'mix',
#   'vanilla',
#   'gradually',
#   'stir',
#   'confectioners',
#   'sugar',
#   'store',
#   'refrigerator',
#   'use'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'large',
#   'bowl',
#   'cream',
#   'butter',
#   'butter',
#   'flavored',
#   'shortening',
#   'brown',
#   'sugar',
#   'white',
#   'sugar',
#   'eggs',
#   'vanilla',
#   'smooth',
#   'combine',
#   'flour',
#   'baking',
#   'soda',
#   'cinnamon',
#   'cloves',
#   'salt',
#   'stir',
#   'sugar',
#   'mixture',
#   'stir',
#   'oats',
#   'raisins',
#   'drop',
#   'rounded',
#   'fuls',
#   'ungreased',
#   'cookie',
#   'sheets',
#   'bake',
#   'minutes',
#   'light',
#   'golden',
#   'overbake',
#   'let',
#   'cool',
#   'minutes',
#   'removing',
#   'cookie',
#   'sheets',
#   'cool',
#   'completely',
#   'store',
#   'airtight',
#   'container',
#   'sure',
#   'dont',
#   'long'],
#  ['small',
#   'bowl',
#   'mix',
#   'maple',
#   'syrup',
#   'soy',
#   'sauce',
#   'garlic',
#   'garlic',
#   'salt',
#   'pepper',
#   'place',
#   'salmon',
#   'shallow',
#   'glass',
#   'baking',
#   'dish',
#   'coat',
#   'maple',
#   'syrup',
#   'mixture',
#   'cover',
#   'dish',
#   'marinate',
#   'salmon',
#   'refrigerator',
#   'minutes',
#   'turning',
#   'preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'place',
#   'baking',
#   'dish',
#   'preheated',
#   'oven',
#   'bake',
#   'salmon',
#   'uncovered',
#   'minutes',
#   'easily',
#   'flaked',
#   'fork'],
#  ['place',
#   'meat',
#   'slow',
#   'cooker',
#   'small',
#   'bowl',
#   'mix',
#   'flour',
#   'salt',
#   'pepper',
#   'pour',
#   'meat',
#   'stir',
#   'coat',
#   'meat',
#   'flour',
#   'mixture',
#   'stir',
#   'garlic',
#   'bay',
#   'leaf',
#   'paprika',
#   'worcestershire',
#   'sauce',
#   'onion',
#   'beef',
#   'broth',
#   'potatoes',
#   'carrots',
#   'celery',
#   'cover',
#   'cook',
#   'low',
#   'setting',
#   'hours',
#   'high',
#   'setting',
#   'hours'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'lightly',
#   'grease',
#   'x',
#   'baking',
#   'dish',
#   'combine',
#   'melted',
#   'butter',
#   'sugar',
#   'vanilla',
#   'large',
#   'bowl',
#   'beat',
#   'eggs',
#   'time',
#   'mixing',
#   'thoroughly',
#   'blended',
#   'sift',
#   'flour',
#   'cocoa',
#   'powder',
#   'salt',
#   'bowl',
#   'gradually',
#   'stir',
#   'flour',
#   'mixture',
#   'egg',
#   'mixture',
#   'blended',
#   'stir',
#   'chocolate',
#   'morsels',
#   'spread',
#   'batter',
#   'evenly',
#   'prepared',
#   'baking',
#   'dish',
#   'bake',
#   'preheated',
#   'oven',
#   'inserted',
#   'toothpick',
#   'comes',
#   'clean',
#   'minutes',
#   'remove',
#   'cool',
#   'pan',
#   'wire',
#   'rack',
#   'cutting'],
#  ['measure',
#   'flour',
#   'large',
#   'mixing',
#   'bowl',
#   'slowly',
#   'whisk',
#   'milk',
#   'whisk',
#   'salt',
#   'eggs',
#   'cinnamon',
#   'vanilla',
#   'extract',
#   'sugar',
#   'smooth',
#   'heat',
#   'lightly',
#   'oiled',
#   'griddle',
#   'frying',
#   'pan',
#   'medium',
#   'heat',
#   'soak',
#   'bread',
#   'slices',
#   'mixture',
#   'saturated',
#   'cook',
#   'bread',
#   'golden',
#   'brown',
#   'serve',
#   'hot'],
#  ['slow',
#   'cooker',
#   'combine',
#   'meat',
#   'soup',
#   'onion',
#   'worcestershire',
#   'sauce',
#   'water',
#   'cook',
#   'low',
#   'setting',
#   'hours',
#   'high',
#   'setting',
#   'hours',
#   'stir',
#   'cream',
#   'cheese',
#   'serving'],
#  ['medium',
#   'bowl',
#   'cream',
# ...
#   'x',
#   'inch',
#   'baking',
#   'dish',
#   'place',
#   'tortillas',
#   'sauce',
#   'overlapping',
#   'necessary',
#   'spoon',
#   'half',
#   'chicken',
#   'mixture',
#   'tortillas',
#   'sprinkle',
#   'half',
#   'cheese',
#   'half',
#   'sour',
#   'cream',
#   'spoon',
#   'remaining',
#   'enchilada',
#   'sauce',
#   'cheese',
#   'layer',
#   'tortillas',
#   'layer',
#   'remaining',
#   'chicken',
#   'mixture',
#   'tortillas',
#   'cover',
#   'dish',
#   'lid',
#   'aluminum',
#   'foil',
#   'bake',
#   'minutes',
#   'preheated',
#   'oven',
#   'remove',
#   'cover',
#   'sprinkle',
#   'remaining',
#   'cheese',
#   'dot',
#   'sour',
#   'cream',
#   'continue',
#   'cooking',
#   'uncovered',
#   'additional',
#   'minutes',
#   'cheese',
#   'melts',
#   'let',
#   'stand',
#   'minutes',
#   'serving'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'grease',
#   'flour',
#   'muffin',
#   'use',
#   'paper',
#   'liners',
#   'filling',
#   'medium',
#   'bowl',
#   'beat',
#   'cream',
#   'cheese',
#   'soft',
#   'add',
#   'egg',
#   'vanilla',
#   'brown',
#   'sugar',
#   'beat',
#   'smooth',
#   'set',
#   'aside',
#   'streusel',
#   'topping',
#   'medium',
#   'bowl',
#   'mix',
#   'flour',
#   'sugar',
#   'cinnamon',
#   'pecans',
#   'add',
#   'butter',
#   'cut',
#   'fork',
#   'crumbly',
#   'set',
#   'aside',
#   'muffin',
#   'batter',
#   'large',
#   'bowl',
#   'sift',
#   'flour',
#   'sugar',
#   'baking',
#   'powder',
#   'cinnamon',
#   'salt',
#   'center',
#   'flour',
#   'mixture',
#   'add',
#   'eggs',
#   'pumpkin',
#   'olive',
#   'oil',
#   'vanilla',
#   'beat',
#   'smooth',
#   'place',
#   'pumpkin',
#   'mixture',
#   'muffin',
#   'add',
#   'cream',
#   'cheese',
#   'mixture',
#   'right',
#   'middle',
#   'batter',
#   'try',
#   'cream',
#   'cheese',
#   'touching',
#   'paper',
#   'sprinkle',
#   'streusel',
#   'topping',
#   'bake',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'minutes'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'grease',
#   'quart',
#   'larger',
#   'casserole',
#   'dish',
#   'butter',
#   'nonstick',
#   'spray',
#   'layer',
#   'half',
#   'potato',
#   'slices',
#   'casserole',
#   'dish',
#   'dot',
#   'half',
#   'butter',
#   'cut',
#   'pinched',
#   'small',
#   'pieces',
#   'arrange',
#   'half',
#   'garlic',
#   'slices',
#   'potatoes',
#   'pour',
#   'half',
#   'heavy',
#   'cream',
#   'sprinkle',
#   'cheddar',
#   'cheese',
#   'layer',
#   'season',
#   'salt',
#   'pepper',
#   'repeat',
#   'layering',
#   'potatoes',
#   'garlic',
#   'cream',
#   'cheddar',
#   'cheese',
#   'slices',
#   'provolone',
#   'cheese',
#   'season',
#   'salt',
#   'pepper',
#   'bake',
#   'hour',
#   'preheated',
#   'oven',
#   'sprinkle',
#   'parmesan',
#   'romano',
#   'cheese',
#   'create',
#   'semi',
#   'hard',
#   'cheese',
#   'crust',
#   'continue',
#   'baking',
#   'uncovered',
#   'minutes',
#   'potatoes',
#   'tender',
#   'tested',
#   'fork'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'spoon',
#   'fruit',
#   'evenly',
#   'tortillas',
#   'sprinkle',
#   'cinnamon',
#   'roll',
#   'tortillas',
#   'place',
#   'seam',
#   'lightly',
#   'greased',
#   'x',
#   'baking',
#   'pan',
#   'bring',
#   'margarine',
#   'sugars',
#   'water',
#   'boil',
#   'medium',
#   'sauce',
#   'pan',
#   'reduce',
#   'heat',
#   'simmer',
#   'stirring',
#   'constantly',
#   'minutes',
#   'pour',
#   'sauce',
#   'evenly',
#   'tortillas',
#   'sprinkle',
#   'extra',
#   'cinnamon',
#   'desired',
#   'bake',
#   'preheated',
#   'oven',
#   'minutes',
#   'makes',
#   'large',
#   'tortillas',
#   'cut',
#   'half',
#   'serve'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'spray',
#   'x',
#   'inch',
#   'pan',
#   'non',
#   'stick',
#   'cooking',
#   'spray',
#   'large',
#   'bowl',
#   'combine',
#   'potatoes',
#   'butter',
#   'salt',
#   'pepper',
#   'onions',
#   'soup',
#   'cheese',
#   'gently',
#   'mix',
#   'pour',
#   'prepared',
#   'pan',
#   'dish',
#   'bake',
#   'preheated',
#   'oven',
#   'browned',
#   'minutes'],
#  ['heat',
#   'olive',
#   'oil',
#   'large',
#   'saucepan',
#   'medium',
#   'heat',
#   'cook',
#   'onion',
#   'lightly',
#   'brown',
#   'mix',
#   'cloves',
#   'garlic',
#   'cook',
#   'minute',
#   'stir',
#   'tomatoes',
#   'tomato',
#   'paste',
#   'water',
#   'sugar',
#   'oregano',
#   'bay',
#   'leaf',
#   'season',
#   'salt',
#   'pepper',
#   'bring',
#   'boil',
#   'reduce',
#   'heat',
#   'low',
#   'simmer',
#   'preparing',
#   'meatballs',
#   'bowl',
#   'mix',
#   'ground',
#   'round',
#   'bread',
#   'crumbs',
#   'remaining',
#   'oregano',
#   'remaining',
#   'garlic',
#   'parsley',
#   'eggs',
#   'cheese',
#   'season',
#   'salt',
#   'pepper',
#   'roll',
#   'inch',
#   'balls',
#   'drop',
#   'sauce',
#   'cook',
#   'minutes',
#   'sauce',
#   'internal',
#   'temperature',
#   'meatballs',
#   'reaches',
#   'minimum',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'bring',
#   'large',
#   'pot',
#   'lightly',
#   'salted',
#   'water',
#   'boil',
#   'stir',
#   'spaghetti',
#   'cook',
#   'minutes',
#   'al',
#   'dente',
#   'drain',
#   'serve',
#   'meatballs',
#   'sauce',
#   'cooked',
#   'spaghetti'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'rinse',
#   'chicken',
#   'thoroughly',
#   'inside',
#   'cold',
#   'running',
#   'water',
#   'remove',
#   'fat',
#   'pat',
#   'dry',
#   'paper',
#   'towels',
#   'chicken',
#   'small',
#   'baking',
#   'pan',
#   'rub',
#   'olive',
#   'oil',
#   'mix',
#   'salt',
#   'pepper',
#   'oregano',
#   'basil',
#   'paprika',
#   'cayenne',
#   'pepper',
#   'sprinkle',
#   'chicken',
#   'roast',
#   'chicken',
#   'preheated',
#   'oven',
#   'minutes',
#   'lower',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'continue',
#   'roasting',
#   'minimum',
#   'internal',
#   'temperature',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'minutes',
#   'let',
#   'cool',
#   'minutes',
#   'serve'],
#  ['medium',
#   'size',
#   'bowl',
#   'mash',
#   'cream',
#   'cheese',
#   'mix',
#   'dressing',
#   'mix',
#   'cheddar',
#   'cheese',
#   'cream',
#   'cheese',
#   'shape',
#   'mixture',
#   'ball',
#   'roll',
#   'ball',
#   'nuts',
#   'refrigerate',
#   'covered',
#   'ready',
#   'serve',
#   'yum'],
#  ['large',
#   'skillet',
#   'heat',
#   'oil',
#   'high',
#   'heat',
#   'saute',
#   'onion',
#   'translucent',
#   'add',
#   'stew',
#   'meat',
#   'cook',
#   'high',
#   'heat',
#   'meat',
#   'browned',
#   'sides',
#   'minutes',
#   'pour',
#   'water',
#   'soy',
#   'sauce',
#   'worcestershire',
#   'sauce',
#   'skillet',
#   'stir',
#   'garlic',
#   'powder',
#   'salt',
#   'pepper',
#   'bring',
#   'boil',
#   'reduce',
#   'heat',
#   'cover',
#   'simmer',
#   'hours',
#   'combine',
#   'gravy',
#   'mix',
#   'water',
#   'mix',
#   'thoroughly',
#   'stir',
#   'meat',
#   'mixture',
#   'bring',
#   'boil',
#   'stirring',
#   'frequently',
#   'slightly',
#   'thickened'],
#  ['large',
#   'skillet',
#   'melt',
#   'butter',
#   'medium',
#   'heat',
#   'cook',
#   'chops',
#   'butter',
#   'turning',
#   'brown',
#   'evenly',
#   'pour',
#   'wine',
#   'season',
#   'salt',
#   'pepper',
#   'rosemary',
#   'garlic',
#   'simmer',
#   'uncovered',
#   'minutes',
#   'chops',
#   'tender',
#   'transfer',
#   'pork',
#   'chops',
#   'serving',
#   'plates',
#   'spoon',
#   'sauce',
#   'meat'],
#  ['pour',
#   'chocolate',
#   'syrup',
#   'medium',
#   'microwave',
#   'safe',
#   'bowl',
#   'microwave',
#   'hot',
#   'minutes',
#   'high',
#   'stopping',
#   'seconds',
#   'allow',
#   'boil',
#   'stir',
#   'peanut',
#   'butter',
#   'hot',
#   'chocolate',
#   'smooth',
#   'allow',
#   'cool',
#   'room',
#   'temperature',
#   'line',
#   'x',
#   'inch',
#   'dish',
#   'layer',
#   'ice',
#   'cream',
#   'sandwiches',
#   'spread',
#   'half',
#   'whipped',
#   'topping',
#   'sandwiches',
#   'spoon',
#   'half',
#   'chocolate',
#   'mixture',
#   'half',
#   'peanuts',
#   'repeat',
#   'layers',
#   'freeze',
#   'firm',
#   'hour',
#   'cut',
#   'squares',
#   'serve'],
#  ['grease',
#   'inch',
#   'bundt',
#   'pan',
#   'preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'large',
#   'bowl',
#   'stir',
#   'cake',
#   'mix',
#   'pudding',
#   'mix',
#   'center',
#   'pour',
#   'orange',
#   'juice',
#   'oil',
#   'eggs',
#   'lemon',
#   'extract',
#   'beat',
#   'low',
#   'speed',
#   'blended',
#   'scrape',
#   'bowl',
#   'beat',
#   'minutes',
#   'medium',
#   'speed',
#   'pour',
#   'batter',
#   'prepared',
#   'pan',
#   'bake',
#   'preheated',
#   'oven',
#   'minutes',
#   'let',
#   'cool',
#   'pan',
#   'minutes',
#   'turn',
#   'wire',
#   'rack',
#   'cool',
#   'completely',
#   'saucepan',
#   'medium',
#   'heat',
#   'cook',
#   'orange',
#   'juice',
#   'sugar',
#   'butter',
#   'minutes',
#   'drizzle',
#   'cake'],
#  ['combine',
#   'egg',
#   'yolks',
#   'sugar',
#   'double',
#   'boiler',
#   'boiling',
#   'water',
#   'reduce',
#   'heat',
#   'low',
#   'cook',
#   'minutes',
#   'stirring',
#   'constantly',
#   'remove',
#   'heat',
#   'whip',
#   'yolks',
#   'lemon',
#   'colored',
#   'add',
#   'mascarpone',
#   'whipped',
#   'yolks',
#   'beat',
#   'combined',
#   'separate',
#   'bowl',
#   'whip',
#   'cream',
#   'stiff',
#   'peaks',
#   'gently',
#   'fold',
#   'yolk',
#   'mixture',
#   'set',
#   'aside',
#   'split',
#   'lady',
#   'fingers',
#   'half',
#   'line',
#   'sides',
#   'large',
#   'glass',
#   'bowl',
#   'brush',
#   'coffee',
#   'liqueur',
#   'spoon',
#   'half',
#   'cream',
#   'filling',
#   'lady',
#   'fingers',
#   'repeat',
#   'ladyfingers',
#   'coffee',
#   'liqueur',
#   'filling',
#   'layers',
#   'garnish',
#   'cocoa',
#   'chocolate',
#   'curls',
#   'refrigerate',
#   'hours',
#   'overnight',
#   'chocolate',
#   'curls',
#   'use',
#   'vegetable',
#   'peeler',
#   'run',
#   'edge',
#   'chocolate',
#   'bar'],
#  ['preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'season',
#   'chicken',
#   'salt',
#   'pepper',
#   'taste',
#   'stuff',
#   'onion',
#   'rosemary',
#   'place',
#   'chicken',
#   'x',
#   'inch',
#   'baking',
#   'dish',
#   'roasting',
#   'dish',
#   'roast',
#   'preheated',
#   'oven',
#   'hours',
#   'chicken',
#   'cooked',
#   'juices',
#   'run',
#   'clear',
#   'cooking',
#   'time',
#   'vary',
#   'bit',
#   'depending',
#   'size',
#   'bird'],
#  ['bring',
#   'large',
#   'pot',
#   'lightly',
#   'salted',
#   'water',
#   'boil',
#   'add',
#   'pasta',
#   'cook',
#   'minutes',
#   'al',
#   'dente',
#   'drain',
#   'heat',
#   'butter',
#   'olive',
#   'oil',
#   'large',
#   'skillet',
#   'medium',
#   'heat',
#   'saute',
#   'chicken',
#   'garlic',
#   'chicken',
#   'cooked',
#   'reduce',
#   'heat',
#   'stir',
#   'salt',
#   'pepper',
#   'cream',
#   'pesto',
#   'parmesan',
#   'cheese',
#   'cook',
#   'chicken',
#   'longer',
#   'pink',
#   'inside',
#   'stir',
#   'cooked',
#   'pasta'],
#  ['place',
#   'beef',
#   'skillet',
#   'medium',
#   'heat',
#   'cook',
#   'evenly',
#   'brown',
#   'drain',
#   'grease',
#   'place',
#   'beef',
#   'slow',
#   'cooker',
#   'mix',
#   'onion',
#   'celery',
#   'green',
#   'bell',
#   'pepper',
#   'garlic',
#   'tomato',
#   'puree',
#   'kidney',
#   'beans',
#   'cannellini',
#   'beans',
#   'season',
#   'chili',
#   'powder',
#   'parsley',
#   'salt',
#   'basil',
#   'oregano',
#   'black',
#   'pepper',
#   'hot',
#   'pepper',
#   'sauce',
#   'cover',
#   'cook',
#   'hours',
#   'low'],
#  ['small',
#   'bowl',
#   'blend',
#   'flour',
#   'cocoa',
#   'baking',
#   'soda',
#   'mix',
#   'blended',
#   'large',
#   'bowl',
#   'beat',
#   'white',
#   'brown',
#   'sugars',
#   'butter',
#   'margarine',
#   'peanut',
#   'butter',
#   'light',
#   'fluffy',
#   'add',
#   'vanilla',
#   'egg',
#   'beat',
#   'stir',
#   'flour',
#   'mixture',
#   'blended',
#   'set',
#   'aside',
#   'filling',
#   'combine',
#   'confectioners',
#   'sugar',
#   'peanut',
#   'butter',
#   'blend',
#   'roll',
#   'filling',
#   'inch',
#   'balls',
#   'cookie',
#   'floured',
#   'hands',
#   'shape',
#   'dough',
#   'peanut',
#   'butter',
#   'ball',
#   'covering',
#   'completely',
#   'place',
#   'inches',
#   'apart',
#   'ungreased',
#   'cookie',
#   'sheet',
#   'flatten',
#   'glass',
#   'dipped',
#   'white',
#   'sugar',
#   'bake',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'minutes',
#   'cookies',
#   'set',
#   'slightly',
#   'cracked'],
#  ['bring',
#   'large',
#   'pot',
#   'lightly',
#   'salted',
#   'water',
#   'boil',
#   'add',
#   'spaghetti',
#   'cook',
#   'minutes',
#   'al',
#   'dente',
#   'drain',
#   'set',
#   'aside',
#   'large',
#   'skillet',
#   'medium',
#   'high',
#   'heat',
#   'saute',
#   'onions',
#   'green',
#   'peppers',
#   'ground',
#   'beef',
#   'beef',
#   'brown',
#   'onions',
#   'peppers',
#   'add',
#   'tomatoes',
#   'mushrooms',
#   'oregano',
#   'simmer',
#   'uncovered',
#   'minutes',
#   'preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'grease',
#   'x',
#   'inch',
#   'baking',
#   'dish',
#   'place',
#   'half',
#   'cooked',
#   'spaghetti',
#   'prepared',
#   'dish',
#   'half',
#   'meat',
#   'mixture',
#   'sprinkle',
#   'mild',
#   'cheddar',
#   'cheese',
#   'repeat',
#   'medium',
#   'bowl',
#   'mix',
#   'cream',
#   'mushroom',
#   'soup',
#   'water',
#   'smooth',
#   'pour',
#   'casserole',
#   'sprinkle',
#   'parmesan',
#   'cheese',
#   'bake',
#   'preheated',
#   'oven',
#   'minutes',
#   'let',
#   'stand',
#   'minutes',
#   'serving'],
#  ['shallow',
#   'slashes',
#   'skinless',
#   'salmon',
#   'fillets',
#   'place',
#   'fillets',
#   'skin',
#   'glass',
#   'baking',
#   'dish',
#   'medium',
#   'bowl',
#   'whisk',
#   'olive',
#   'oil',
#   'rice',
#   'vinegar',
#   'soy',
#   'sauce',
#   'brown',
#   'sugar',
#   'garlic',
#   'pepper',
#   'onion',
#   'sesame',
#   'oil',
#   'pour',
#   'liquid',
#   'salmon',
#   'cover',
#   'refrigerate',
#   'hours',
#   'preheat',
#   'oven',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'medium',
#   'saucepan',
#   'combine',
#   'rice',
#   'water',
#   'dill',
#   'weed',
#   'cover',
#   'pan',
#   'bring',
#   'boil',
#   'reduce',
#   'heat',
#   'low',
#   'cook',
#   'minutes',
#   'rice',
#   'tender',
#   'water',
#   'absorbed',
#   'allow',
#   'stand',
#   'minutes',
#   'removing',
#   'lid',
#   'fluffing',
#   'rice',
#   'fork',
#   'remove',
#   'cover',
#   'salmon',
#   'bake',
#   'fish',
#   'marinade',
#   'minutes',
#   'fish',
#   'flaked',
#   'fork',
#   'serve',
#   'salmon',
#   'rice',
#   'pour',
#   'sauce'],
#  ['medium',
#   'saucepan',
#   'medium',
#   'heat',
#   'warm',
#   'milk',
#   'water',
#   'sugar',
#   'salt',
#   'remove',
#   'heat',
#   'mix',
#   'eggs',
#   'yeast',
#   'measure',
#   'flour',
#   'large',
#   'bowl',
#   'flour',
#   'pour',
#   'milk',
#   'mixture',
#   'stir',
#   'cover',
#   'lid',
#   'let',
#   'stand',
#   'minutes',
#   'pour',
#   'melted',
#   'margarine',
#   'flour',
#   'mix',
#   'add',
#   'flour',
#   'sticky',
#   'knead',
#   'lightly',
#   'cover',
#   'let',
#   'rise',
#   'minutes',
#   'shape',
#   'dough',
#   'rolls',
#   'place',
#   'baking',
#   'sheet',
#   'let',
#   'rise',
#   'minutes',
#   'bake',
#   'rolls',
#   'preheated',
#   'degrees',
#   'f',
#   'degrees',
#   'c',
#   'oven',
#   'minutes'],
#  ['melt',
#   'butter',
#   'medium',
#   'high',
#   'heat',
#   'iron',
#   'skillet',
#   'remove',
#   'heat',
#   'sprinkle',
#   'brown',
#   'sugar',
#   'evenly',
#   'cover',
#   'butter',
#   'arrange',
#   'pineapple',
#   'rings',
#   'pan',
#   'layer',
#   'deep',
#   'place',
#   'maraschino',
#   'cherry',
#   'center',
#   'pineapple',
#   'ring',
#   'prepare',
#   'cake',
#   'mix',
#   'directed',
#   'manufacturer',
#   'substitute',
#   'pineapple',
#   'juice',
#   'liquid',
#   'directions',
#   'pour',
#   'batter',
#   'pineapple',
#   'layer',
#   'bake',
#   'directed',
#   'cake',
#   'mix',
#   'directions',
#   'cool',
#   'minutes',
#   'carefully',
#   'turn',
#   'plate',
#   'let',
#   'cake',
#   'cool',
#   'stuck',
#   'pan'],
#  ['heat',
#   'olive',
#   'oil',
#   'large',
#   'pot',
#   'medium',
#   'heat',
#   'cook',
#   'onion',
#   'celery',
#   'garlic',
#   'carrots',
#   'hot',
#   'oil',
#   'onion',
#   'translucent',
#   'minutes',
#   'stir',
#   'cubed',
#   'chicken',
#   'chicken',
#   'broth',
#   'bring',
#   'simmer',
#   'stir',
#   'gnocchi',
#   'simmering',
#   'soup',
#   'cook',
#   'begin',
#   'float',
#   'minutes',
#   'stir',
#   'spinach',
#   'cook',
#   'wilted',
#   'additional',
#   'minutes',
#   'whisk',
#   'cornstarch',
#   'cold',
#   'water',
#   'smooth',
#   'stir',
#   'cornstarch',
#   'mixture',
#   'half',
#   'half',
#   'simmering',
#   'soup',
#   'cook',
#   'soup',
#   'thickens',
#   'slightly',
#   'minutes',
#   'season',
#   'taste',
#   'salt',
#   'black',
#   'pepper'],
#  ['place',
#   'chicken',
#   'slow',
#   'cooker',
#   'small',
#   'bowl',
#   'mix',
#   'onion',
#   'garlic',
#   'soy',
#   'sauce',
#   'vinegar',
#   'pour',
#   'chicken',
#   'cook',
#   'low',
#   'hours'],
#  ['place',
#   'corned',
#   'beef',
#   'briskets',
#   'large',
#   'pot',
#   'sprinkle',
#   'spice',
#   'packets',
#   'discard',
#   'save',
#   'uses',
#   'pour',
#   'beer',
#   'pot',
#   'water',
#   'cover',
#   'briskets',
#   'inch',
#   'add',
#   'bay',
#   'leaves',
#   'peppercorns',
#   'garlic',
#   'cloves',
#   'cover',
#   'bring',
#   'boil',
#   'liquid',
#   'comes',
#   'boil',
#   'reduce',
#   'heat',
#   'medium',
#   'low',
#   'simmer',
#   'hours',
#   'checking',
#   'hourly',
#   'adding',
#   'water',
#   'necessary',
#   'meat',
#   'covered',
#   'carefully',
#   'remove',
#   'meat',
#   'pot',
#   'extremely',
#   'tender',
#   'set',
#   'cutting',
#   'board',
#   'allow',
#   'rest',
#   'firms',
#   'bit',
#   'minutes',
#   'slice',
#   'shred',
#   'serve',
#   'discard',
#   'cooking',
#   'liquid',
#   'cook',
#   'cabbage',
#   'vegetables',
#   'desired'],
#  ...]

# %%
pickle.dump(train_data, open("./Data/train_data.pkl", "wb"))
